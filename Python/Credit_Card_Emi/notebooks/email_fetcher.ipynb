# %%
import imaplib
import email
import os
import json
import logging
from datetime import datetime, timedelta
from email.header import decode_header
import sys
from pathlib import Path

# Add src to path for imports
sys.path.append('../src')

print("✅ All libraries imported successfully!")
print(f"📅 Current date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ✅ All libraries imported successfully!
# 📅 Current date: 2025-08-12 12:37:58

# %%
# Configuration for email fetcher
CONFIG = {
    "email_address": "surendharal65@gmail.com",  # Enter your email address
    "password": "ggvgpgpmykcgbphj",       # Enter your app password
    "imap_server": "imap.gmail.com",  # Change based on your provider
    "imap_port": 993,
    "download_folder": "../data/raw_emails",
    "search_criteria": {
        "hdfc_sender": "Emailstatements.cards@hdfcbank.net",
        "idfc_sender": "statement@idfcfirstbank.com",
        "subject_keywords": ["statement", "credit card", "bill", "HDFC", "IDFC", "Your HDFC Bank Titanium Times Card Credit Card Statement",
                             "Your HDFC Bank Insta Jumbo Loan Statement for the month"]
    }
}

# Create necessary directories
os.makedirs(CONFIG['download_folder'], exist_ok=True)
os.makedirs('../config', exist_ok=True)

print("📁 Directory structure created!")
#print("⚠️  IMPORTANT: Please update CONFIG with your email credentials above!")
# Out:
# 📁 Directory structure created!

# %%
# Setup comprehensive logging
def setup_logging():
    """Setup logging for email fetcher"""
    log_format = '%(asctime)s - %(levelname)s - %(message)s'
    
    # Create logs directory
    os.makedirs('../logs', exist_ok=True)
    
    # Setup file and console logging
    logging.basicConfig(
        level=logging.INFO,
        format=log_format,
        handlers=[
            logging.FileHandler('../logs/email_fetcher.log'),
            logging.StreamHandler()
        ]
    )
    return logging.getLogger(__name__)

# Initialize logger
logger = setup_logging()
logger.info("Email Fetcher Phase 1 Started")
# Out:
# 2025-08-12 13:10:46,027 - INFO - Email Fetcher Phase 1 Started

# %%
def connect_to_email(config):
    """Connect to email server using IMAP"""
    try:
        # Connect to IMAP server
        mail = imaplib.IMAP4_SSL(config['imap_server'], config['imap_port'])
        
        # Login with credentials
        mail.login(config['email_address'], config['password'])
        
        logger.info(" Successfully connected to email server")
        return mail
        
    except Exception as e:
        logger.error(f" Failed to connect to email: {str(e)}")
        return None

def test_connection():
    """Test email connection with current config"""
    if not CONFIG['email_address'] or not CONFIG['password']:
        print(" Please update CONFIG with your email credentials first!")
        return False
    
    mail = connect_to_email(CONFIG)
    if mail:
        try:
            # Select INBOX before closing
            mail.select("INBOX")
            mail.close()
            mail.logout()
            print(" Email connection test successful!")
            return True
        except:
            pass
    
    print(" Email connection test failed!")
    return False

# Test the connection
test_connection()
# Out:
# 2025-08-12 13:17:44,070 - INFO -  Successfully connected to email server
#  Email connection test successful!
# True

# %%
def search_credit_card_emails(mail, config, days_back=365):
    """Search for credit card statement emails"""
    try:
        # Select inbox
        mail.select('inbox')
        
        # Calculate date range (going backwards from today)
        end_date = datetime.now()
        start_date = end_date - timedelta(days=days_back)
        start_date_str = start_date.strftime("%d-%b-%Y")
        
        logger.info(f" Searching emails from {start_date_str} to today")
        
        # Multiple search criteria for better coverage
        search_criteria = [
            f'(FROM "{config["search_criteria"]["hdfc_sender"]}" SINCE "{start_date_str}")',
            f'(FROM "{config["search_criteria"]["idfc_sender"]}" SINCE "{start_date_str}")',
            '(SUBJECT "HDFC Credit Card Statement" SINCE "{}")'.format(start_date_str),
            '(SUBJECT "IDFC Credit Card Statement" SINCE "{}")'.format(start_date_str),
            '(SUBJECT "statement" SINCE "{}") (FROM "hdfc")'.format(start_date_str),
            '(SUBJECT "statement" SINCE "{}") (FROM "idfc")'.format(start_date_str),
        ]
        
        all_email_ids = set()  # Use set to avoid duplicates
        
        for criteria in search_criteria:
            try:
                typ, messages = mail.search(None, criteria)
                if messages[0]:
                    email_ids = messages[0].split()
                    all_email_ids.update(email_ids)
                    logger.info(f"Found {len(email_ids)} emails with criteria: {criteria}")
            except Exception as e:
                logger.warning(f"Search failed for criteria {criteria}: {str(e)}")
        
        unique_email_ids = list(all_email_ids)
        logger.info(f" Total unique emails found: {len(unique_email_ids)}")
        
        return unique_email_ids
        
    except Exception as e:
        logger.error(f" Search failed: {str(e)}")
        return []

# Test search function (will run in next cell with actual connection)
print(" Search functions defined successfully!")
# Out:
#  Search functions defined successfully!

# %%
def decode_header_value(header_value):
    """Decode email header value"""
    if header_value:
        try:
            decoded = decode_header(header_value)[0]
            if isinstance(decoded[0], bytes):
                return decoded[0].decode(decoded[1] or 'utf-8')
            return decoded[0]
        except:
            return str(header_value)
    return ""

def identify_bank(sender):
    """Identify bank from sender email"""
    sender_lower = sender.lower()
    if 'hdfc' in sender_lower:
        return 'HDFC'
    elif 'idfc' in sender_lower:
        return 'IDFC'
    elif 'axis' in sender_lower:
        return 'AXIS'
    elif 'sbi' in sender_lower:
        return 'SBI'
    elif 'icici' in sender_lower:
        return 'ICICI'
    else:
        return 'UNKNOWN'

def make_safe_filename(filename):
    """Make filename safe for filesystem"""
    unsafe_chars = '<>:"/\\|?*'
    for char in unsafe_chars:
        filename = filename.replace(char, '_')
    return filename

def is_pdf_attachment(part):
    """Check if email part is a PDF attachment"""
    content_disposition = part.get("Content-Disposition", "")
    content_type = part.get_content_type()
    filename = part.get_filename()
    
    is_attachment = "attachment" in content_disposition
    is_pdf = (content_type == "application/pdf" or 
              (filename and filename.lower().endswith('.pdf')))
    
    return is_attachment and is_pdf

print(" PDF processing functions defined successfully!")
# Out:
#  PDF processing functions defined successfully!

# %%
def extract_pdf_attachments(mail, email_ids, config):
    """Extract PDF attachments from emails"""
    pdf_files = []
    total_emails = len(email_ids)
    
    logger.info(f" Processing {total_emails} emails for PDF attachments...")
    
    for idx, email_id in enumerate(email_ids, 1):
        try:
            logger.info(f"Processing email {idx}/{total_emails} (ID: {email_id.decode()})")
            
            # Fetch email
            typ, msg_data = mail.fetch(email_id, '(RFC822)')
            
            for response_part in msg_data:
                if isinstance(response_part, tuple):
                    # Parse email message
                    msg = email.message_from_bytes(response_part[1])
                    
                    # Get email details
                    subject = decode_header_value(msg["Subject"])
                    sender = decode_header_value(msg.get("From"))
                    date = msg.get("Date")
                    
                    logger.info(f" Processing: {subject[:50]}... from {sender}")
                    
                    # Process attachments
                    if msg.is_multipart():
                        for part in msg.walk():
                            if is_pdf_attachment(part):
                                pdf_info = save_pdf_attachment(
                                    part, subject, sender, date, config
                                )
                                if pdf_info:
                                    pdf_files.append(pdf_info)
                                    logger.info(f" Downloaded: {pdf_info['filename']}")
                                    
        except Exception as e:
            logger.error(f" Error processing email {email_id}: {str(e)}")
            continue
    
    return pdf_files

def save_pdf_attachment(part, subject, sender, date, config):
    """Save PDF attachment to disk"""
    try:
        filename = part.get_filename()
        if not filename:
            return None
            
        # Clean filename
        safe_filename = make_safe_filename(filename)
        
        # Create timestamp for unique naming
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        
        # Determine bank type from sender
        bank_type = identify_bank(sender)
        
        # Create final filename
        final_filename = f"{bank_type}_{timestamp}_{safe_filename}"
        
        # Ensure download directory exists
        download_path = config['download_folder']
        os.makedirs(download_path, exist_ok=True)
        
        # Full file path
        file_path = os.path.join(download_path, final_filename)
        
        # Save file
        with open(file_path, 'wb') as f:
            f.write(part.get_payload(decode=True))
        
        file_size = os.path.getsize(file_path)
        logger.info(f" Saved PDF: {final_filename} ({file_size} bytes)")
        
        return {
            'filename': final_filename,
            'file_path': file_path,
            'bank': bank_type,
            'subject': subject,
            'sender': sender,
            'date': date,
            'size': file_size,
            'download_timestamp': datetime.now().isoformat()
        }
        
    except Exception as e:
        logger.error(f" Error saving PDF: {str(e)}")
        return None

print(" PDF download functions defined successfully!")
# Out:
#  PDF download functions defined successfully!

# %%
def run_complete_email_fetch(config, since_date, before_date):
    """Fetch credit card statement emails between two given dates."""
    logger.info(f" Fetching Credit Card Emails from {since_date} to {before_date}")

    if not config['email_address'] or not config['password']:
        logger.error(" Email credentials not provided in config!")
        return []

    all_pdfs = []
    mail = connect_to_email(config)
    if not mail:
        return []

    try:
        # Convert string dates to datetime objects
        start_date = datetime.strptime(since_date, "%d-%b-%Y")
        end_date = datetime.strptime(before_date, "%d-%b-%Y") - timedelta(days=1)

        # Search emails for this date range
        email_ids = search_credit_card_emails_between(mail, config, start_date, end_date)

        if not email_ids:
            logger.info(f" No emails found in this date range.")
            return []

        # Extract PDFs
        pdf_files = extract_pdf_attachments(mail, email_ids, config)
        all_pdfs.extend(pdf_files)

        # Save summary
        summary = {
            'total_emails_found': len(email_ids),
            'total_pdfs_downloaded': len(all_pdfs),
            'download_timestamp': datetime.now().isoformat(),
            'date_range': {
                'since': since_date,
                'before': before_date
            },
            'pdf_files': all_pdfs
        }
        summary_path = os.path.join(config['download_folder'], f'download_summary.json')
        with open(summary_path, 'w') as f:
            json.dump(summary, f, indent=2)

        logger.info(f" Done: {len(email_ids)} emails, {len(pdf_files)} PDFs.")
        return all_pdfs

    finally:
        try:
            mail.close()
            mail.logout()
            logger.info(" Email connection closed")
        except:
            pass

# %%
def search_credit_card_emails_between(mail, config, start_date, end_date):
    """Search for credit card statement emails between two dates."""
    try:
        mail.select('inbox')
        start_str = start_date.strftime("%d-%b-%Y")
        end_str = end_date.strftime("%d-%b-%Y")

        logger.info(f"Searching emails from {start_str} to {end_str}")

        search_criteria = [
            f'(FROM "{config["search_criteria"]["hdfc_sender"]}" SINCE "{start_str}" BEFORE "{end_str}")',
            f'(FROM "{config["search_criteria"]["idfc_sender"]}" SINCE "{start_str}" BEFORE "{end_str}")',
            f'(SUBJECT "HDFC Credit Card Statement" SINCE "{start_str}" BEFORE "{end_str}")',
            f'(SUBJECT "IDFC Credit Card Statement" SINCE "{start_str}" BEFORE "{end_str}")',
            f'(SUBJECT "statement" SINCE "{start_str}" BEFORE "{end_str}") (FROM "hdfc")',
            f'(SUBJECT "statement" SINCE "{start_str}" BEFORE "{end_str}") (FROM "idfc")',
        ]

        all_email_ids = set()

        for criteria in search_criteria:
            try:
                typ, messages = mail.search(None, criteria)
                if messages[0]:
                    email_ids = messages[0].split()
                    all_email_ids.update(email_ids)
                    logger.info(f"Found {len(email_ids)} emails with criteria: {criteria}")
            except Exception as e:
                logger.warning(f"Search failed for criteria {criteria}: {str(e)}")

        return list(all_email_ids)

    except Exception as e:
        logger.error(f"Search failed: {str(e)}")
        return []

# %%
def run_yearly_email_fetch(CONFIG, start_year=None):
    """Fetch credit card statement emails year-by-year until no results are found."""
    if not CONFIG['email_address'] or not CONFIG['password']:
        print("STOP! Please update CONFIG with your email credentials first!")
        return

    if start_year is None:
        start_year = datetime.now().year  # Current year

    current_year = start_year
    all_downloaded_files = []

    print("Starting Year-by-Year Email Fetching Process...")
    print(f"Email: {CONFIG['email_address']}")
    print("=" * 50)

    while True:
        since_date = f"01-Jan-{current_year}"
        before_date = f"01-Jan-{current_year + 1}"

        print(f"\n Processing Year: {current_year}")
        print(f"Searching from {since_date} to {before_date}...")

        downloaded_files = run_complete_email_fetch(
            CONFIG,
            since_date=since_date,
            before_date=before_date
        )

        if not downloaded_files:
            print(f" No emails found for {current_year}. Stopping search.")
            break

        print(f" {len(downloaded_files)} PDFs downloaded for {current_year}")
        all_downloaded_files.extend(downloaded_files)

        import time
        time.sleep(3)  # Avoid Gmail rate limits

        current_year -= 1

    print("=" * 50)
    print(" All Years Processing Complete!")
    print(f"Total PDFs downloaded: {len(all_downloaded_files)}")
    return all_downloaded_files


# Run it
all_files = run_yearly_email_fetch(CONFIG)
# Out:
# 2025-08-12 18:19:07,726 - INFO -  Fetching Credit Card Emails from 01-Jan-2025 to 01-Jan-2026
# Starting Year-by-Year Email Fetching Process...
# Email: surendharal65@gmail.com
# ==================================================
#
#  Processing Year: 2025
# Searching from 01-Jan-2025 to 01-Jan-2026...
# 2025-08-12 18:19:09,229 - INFO -  Successfully connected to email server
# 2025-08-12 18:19:09,740 - INFO - Searching emails from 01-Jan-2025 to 31-Dec-2025
# 2025-08-12 18:19:10,344 - INFO - Found 5 emails with criteria: (FROM "Emailstatements.cards@hdfcbank.net" SINCE "01-Jan-2025" BEFORE "31-Dec-2025")
# 2025-08-12 18:19:11,294 - INFO - Found 5 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2025" BEFORE "31-Dec-2025") (FROM "hdfc")
# 2025-08-12 18:19:11,598 - INFO - Found 17 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2025" BEFORE "31-Dec-2025") (FROM "idfc")
# 2025-08-12 18:19:11,601 - INFO -  Processing 22 emails for PDF attachments...
# 2025-08-12 18:19:11,604 - INFO - Processing email 1/22 (ID: 84442)
# 2025-08-12 18:19:12,664 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:12,687 - INFO -  Saved PDF: IDFC_20250812_181912_20000002170120_22072025_111137192.pdf (512464 bytes)
# 2025-08-12 18:19:12,696 - INFO -  Downloaded: IDFC_20250812_181912_20000002170120_22072025_111137192.pdf
# 2025-08-12 18:19:12,698 - INFO - Processing email 2/22 (ID: 78459)
# 2025-08-12 18:19:13,320 - INFO -  Processing: Your Account Statement for the month of December 2... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:13,333 - INFO -  Saved PDF: IDFC_20250812_181913_574101XXXX.pdf (170038 bytes)
# 2025-08-12 18:19:13,338 - INFO -  Downloaded: IDFC_20250812_181913_574101XXXX.pdf
# 2025-08-12 18:19:13,344 - INFO - Processing email 3/22 (ID: 80229)
# 2025-08-12 18:19:14,081 - INFO -  Processing: Your Account Statement for the month of February 2... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:14,090 - INFO -  Saved PDF: IDFC_20250812_181914_574101XXXX.pdf (175953 bytes)
# 2025-08-12 18:19:14,094 - INFO -  Downloaded: IDFC_20250812_181914_574101XXXX.pdf
# 2025-08-12 18:19:14,097 - INFO - Processing email 4/22 (ID: 81403)
# 2025-08-12 18:19:15,032 - INFO -  Processing: Your HDFC Bank Insta Jumbo Loan Statement for the ... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:19:15,045 - INFO -  Saved PDF: HDFC_20250812_181915_jumbo_loan_0001019020020455148.pdf (203494 bytes)
# 2025-08-12 18:19:15,049 - INFO -  Downloaded: HDFC_20250812_181915_jumbo_loan_0001019020020455148.pdf
# 2025-08-12 18:19:15,052 - INFO - Processing email 5/22 (ID: 80633)
# 2025-08-12 18:19:15,725 - INFO -  Processing: Your HDFC Bank Insta Jumbo Loan Statement for the ... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:19:15,735 - INFO -  Saved PDF: HDFC_20250812_181915_jumbo_loan_0001019020020455148.pdf (204163 bytes)
# 2025-08-12 18:19:15,739 - INFO -  Downloaded: HDFC_20250812_181915_jumbo_loan_0001019020020455148.pdf
# 2025-08-12 18:19:15,745 - INFO - Processing email 6/22 (ID: 84365)
# 2025-08-12 18:19:16,778 - INFO -  Processing: Your FIRST Power Plus Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:16,800 - INFO -  Saved PDF: IDFC_20250812_181916_90300001872873_20072025_120319539.pdf (478344 bytes)
# 2025-08-12 18:19:16,807 - INFO -  Downloaded: IDFC_20250812_181916_90300001872873_20072025_120319539.pdf
# 2025-08-12 18:19:16,812 - INFO - Processing email 7/22 (ID: 81828)
# 2025-08-12 18:19:17,429 - INFO -  Processing: Your Account Statement for the month of April 2025... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:17,442 - INFO -  Saved PDF: IDFC_20250812_181917_574101XXXX.pdf (163906 bytes)
# 2025-08-12 18:19:17,446 - INFO -  Downloaded: IDFC_20250812_181917_574101XXXX.pdf
# 2025-08-12 18:19:17,450 - INFO - Processing email 8/22 (ID: 82339)
# 2025-08-12 18:19:18,679 - INFO -  Processing: Your FIRST Power Plus Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:18,695 - INFO -  Saved PDF: IDFC_20250812_181918_90300001872873_20052025_133715846.pdf (540173 bytes)
# 2025-08-12 18:19:18,702 - INFO -  Downloaded: IDFC_20250812_181918_90300001872873_20052025_133715846.pdf
# 2025-08-12 18:19:18,708 - INFO - Processing email 9/22 (ID: 81599)
# 2025-08-12 18:19:19,759 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:19,778 - INFO -  Saved PDF: IDFC_20250812_181919_20000002170120_23042025_115543174.pdf (457966 bytes)
# 2025-08-12 18:19:19,782 - INFO -  Downloaded: IDFC_20250812_181919_20000002170120_23042025_115543174.pdf
# 2025-08-12 18:19:19,789 - INFO - Processing email 10/22 (ID: 80050)
# 2025-08-12 18:19:20,844 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:20,857 - INFO -  Saved PDF: IDFC_20250812_181920_20000002170120_22022025_143507512.pdf (460756 bytes)
# 2025-08-12 18:19:20,859 - INFO -  Downloaded: IDFC_20250812_181920_20000002170120_22022025_143507512.pdf
# 2025-08-12 18:19:20,862 - INFO - Processing email 11/22 (ID: 79798)
# 2025-08-12 18:19:21,751 - INFO -  Processing: Your HDFC Bank Insta Jumbo Loan Statement for the ... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:19:21,765 - INFO -  Saved PDF: HDFC_20250812_181921_jumbo_loan_0001019020020455148.pdf (205762 bytes)
# 2025-08-12 18:19:21,771 - INFO -  Downloaded: HDFC_20250812_181921_jumbo_loan_0001019020020455148.pdf
# 2025-08-12 18:19:21,772 - INFO - Processing email 12/22 (ID: 78855)
# 2025-08-12 18:19:22,545 - INFO -  Processing: Your HDFC Bank Insta Jumbo Loan Statement for the ... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:19:22,557 - INFO -  Saved PDF: HDFC_20250812_181922_jumbo_loan_0001019020020455148.pdf (205756 bytes)
# 2025-08-12 18:19:22,560 - INFO -  Downloaded: HDFC_20250812_181922_jumbo_loan_0001019020020455148.pdf
# 2025-08-12 18:19:22,563 - INFO - Processing email 13/22 (ID: 82709)
# 2025-08-12 18:19:23,204 - INFO -  Processing: Your Account Statement for the month of May 2025... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:23,215 - INFO -  Saved PDF: IDFC_20250812_181923_574101XXXX.pdf (175938 bytes)
# 2025-08-12 18:19:23,223 - INFO -  Downloaded: IDFC_20250812_181923_574101XXXX.pdf
# 2025-08-12 18:19:23,226 - INFO - Processing email 14/22 (ID: 82444)
# 2025-08-12 18:19:24,091 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:24,103 - INFO -  Saved PDF: IDFC_20250812_181924_20000002170120_22052025_120616270.pdf (457890 bytes)
# 2025-08-12 18:19:24,107 - INFO -  Downloaded: IDFC_20250812_181924_20000002170120_22052025_120616270.pdf
# 2025-08-12 18:19:24,111 - INFO - Processing email 15/22 (ID: 84729)
# 2025-08-12 18:19:24,722 - INFO -  Processing: Your Account Statement for the month of July 2025... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:24,737 - INFO -  Saved PDF: IDFC_20250812_181924_574101XXXX.pdf (163637 bytes)
# 2025-08-12 18:19:24,741 - INFO -  Downloaded: IDFC_20250812_181924_574101XXXX.pdf
# 2025-08-12 18:19:24,744 - INFO - Processing email 16/22 (ID: 79369)
# 2025-08-12 18:19:25,304 - INFO -  Processing: Your Account Statement for the month of January 20... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:25,319 - INFO -  Saved PDF: IDFC_20250812_181925_574101XXXX.pdf (166828 bytes)
# 2025-08-12 18:19:25,324 - INFO -  Downloaded: IDFC_20250812_181925_574101XXXX.pdf
# 2025-08-12 18:19:25,331 - INFO - Processing email 17/22 (ID: 83265)
# 2025-08-12 18:19:26,410 - INFO -  Processing: Your FIRST Power Plus Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:26,426 - INFO -  Saved PDF: IDFC_20250812_181926_90300001872873_20062025_131901330.pdf (480266 bytes)
# 2025-08-12 18:19:26,429 - INFO -  Downloaded: IDFC_20250812_181926_90300001872873_20062025_131901330.pdf
# 2025-08-12 18:19:26,432 - INFO - Processing email 18/22 (ID: 83347)
# 2025-08-12 18:19:27,611 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:27,625 - INFO -  Saved PDF: IDFC_20250812_181927_20000002170120_22062025_115751719.pdf (438063 bytes)
# 2025-08-12 18:19:27,629 - INFO -  Downloaded: IDFC_20250812_181927_20000002170120_22062025_115751719.pdf
# 2025-08-12 18:19:27,640 - INFO - Processing email 19/22 (ID: 81058)
# 2025-08-12 18:19:28,195 - INFO -  Processing: Your Account Statement for the month of March 2025... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:28,207 - INFO -  Saved PDF: IDFC_20250812_181928_574101XXXX.pdf (159353 bytes)
# 2025-08-12 18:19:28,209 - INFO -  Downloaded: IDFC_20250812_181928_574101XXXX.pdf
# 2025-08-12 18:19:28,213 - INFO - Processing email 20/22 (ID: 83667)
# 2025-08-12 18:19:28,830 - INFO -  Processing: Your Account Statement for the month of June 2025... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:28,838 - INFO -  Saved PDF: IDFC_20250812_181928_574101XXXX.pdf (169679 bytes)
# 2025-08-12 18:19:28,842 - INFO -  Downloaded: IDFC_20250812_181928_574101XXXX.pdf
# 2025-08-12 18:19:28,844 - INFO - Processing email 21/22 (ID: 81405)
# 2025-08-12 18:19:29,530 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:19:29,540 - INFO -  Saved PDF: HDFC_20250812_181929_5241XXXXXXXXXX70_15-04-2025.PDF (199629 bytes)
# 2025-08-12 18:19:29,542 - INFO -  Downloaded: HDFC_20250812_181929_5241XXXXXXXXXX70_15-04-2025.PDF
# 2025-08-12 18:19:29,544 - INFO - Processing email 22/22 (ID: 80800)
# 2025-08-12 18:19:30,440 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:30,451 - INFO -  Saved PDF: IDFC_20250812_181930_20000002170120_23032025_113032236.pdf (459322 bytes)
# 2025-08-12 18:19:30,455 - INFO -  Downloaded: IDFC_20250812_181930_20000002170120_23032025_113032236.pdf
# 2025-08-12 18:19:30,468 - INFO -  Done: 22 emails, 22 PDFs.
# 2025-08-12 18:19:31,335 - INFO -  Email connection closed
#  22 PDFs downloaded for 2025
# 2025-08-12 18:19:34,340 - INFO -  Fetching Credit Card Emails from 01-Jan-2024 to 01-Jan-2025
#  Processing Year: 2024
# Searching from 01-Jan-2024 to 01-Jan-2025...
# 2025-08-12 18:19:35,588 - INFO -  Successfully connected to email server
# 2025-08-12 18:19:36,116 - INFO - Searching emails from 01-Jan-2024 to 31-Dec-2024
# 2025-08-12 18:19:36,894 - INFO - Found 18 emails with criteria: (FROM "Emailstatements.cards@hdfcbank.net" SINCE "01-Jan-2024" BEFORE "31-Dec-2024")
# 2025-08-12 18:19:37,833 - INFO - Found 19 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2024" BEFORE "31-Dec-2024") (FROM "hdfc")
# 2025-08-12 18:19:38,121 - INFO - Found 28 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2024" BEFORE "31-Dec-2024") (FROM "idfc")
# 2025-08-12 18:19:38,124 - INFO -  Processing 47 emails for PDF attachments...
# 2025-08-12 18:19:38,126 - INFO - Processing email 1/47 (ID: 68119)
# 2025-08-12 18:19:39,826 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:39,853 - INFO -  Saved PDF: IDFC_20250812_181939_20000002170120_22012024_100415081.pdf (996948 bytes)
# 2025-08-12 18:19:39,856 - INFO -  Downloaded: IDFC_20250812_181939_20000002170120_22012024_100415081.pdf
# 2025-08-12 18:19:39,859 - INFO - Processing email 2/47 (ID: 72780)
# 2025-08-12 18:19:41,324 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:41,359 - INFO -  Saved PDF: IDFC_20250812_181941_20000002170120_22062024_122805981.pdf (1004991 bytes)
# 2025-08-12 18:19:41,365 - INFO -  Downloaded: IDFC_20250812_181941_20000002170120_22062024_122805981.pdf
# 2025-08-12 18:19:41,368 - INFO - Processing email 3/47 (ID: 69020)
# 2025-08-12 18:19:42,736 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:42,757 - INFO -  Saved PDF: IDFC_20250812_181942_20000002170120_22022024_120310511.pdf (996242 bytes)
# 2025-08-12 18:19:42,764 - INFO -  Downloaded: IDFC_20250812_181942_20000002170120_22022024_120310511.pdf
# 2025-08-12 18:19:42,771 - INFO - Processing email 4/47 (ID: 77957)
# 2025-08-12 18:19:43,303 - INFO -  Processing: Your HDFC Bank Insta Jumbo Loan Statement for the ... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:19:43,311 - INFO -  Saved PDF: HDFC_20250812_181943_jumbo_loan_0001019020020455148.pdf (203826 bytes)
# 2025-08-12 18:19:43,315 - INFO -  Downloaded: HDFC_20250812_181943_jumbo_loan_0001019020020455148.pdf
# 2025-08-12 18:19:43,318 - INFO - Processing email 5/47 (ID: 71775)
# 2025-08-12 18:19:44,624 - INFO -  Processing: Your FIRST Power Plus Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:44,664 - INFO -  Saved PDF: IDFC_20250812_181944_90300001872873_20052024_125937266.pdf (794965 bytes)
# 2025-08-12 18:19:44,667 - INFO -  Downloaded: IDFC_20250812_181944_90300001872873_20052024_125937266.pdf
# 2025-08-12 18:19:44,671 - INFO - Processing email 6/47 (ID: 77494)
# 2025-08-12 18:19:45,301 - INFO -  Processing: Your Account Statement for the month of November 2... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:45,310 - INFO -  Saved PDF: IDFC_20250812_181945_574101XXXX.pdf (165152 bytes)
# 2025-08-12 18:19:45,313 - INFO -  Downloaded: IDFC_20250812_181945_574101XXXX.pdf
# 2025-08-12 18:19:45,318 - INFO - Processing email 7/47 (ID: 77059)
# 2025-08-12 18:19:45,928 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:19:45,941 - INFO -  Saved PDF: HDFC_20250812_181945_5241XXXXXXXXXX70_15-11-2024.PDF (206223 bytes)
# 2025-08-12 18:19:45,944 - INFO -  Downloaded: HDFC_20250812_181945_5241XXXXXXXXXX70_15-11-2024.PDF
# 2025-08-12 18:19:45,947 - INFO - Processing email 8/47 (ID: 69800)
# 2025-08-12 18:19:46,437 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:19:46,450 - INFO -  Saved PDF: HDFC_20250812_181946_5241XXXXXXXXXX70_15-03-2024.PDF (204597 bytes)
# 2025-08-12 18:19:46,454 - INFO -  Downloaded: HDFC_20250812_181946_5241XXXXXXXXXX70_15-03-2024.PDF
# 2025-08-12 18:19:46,458 - INFO - Processing email 9/47 (ID: 67936)
# 2025-08-12 18:19:46,929 - INFO -  Processing: Your HDFC Bank - Jumbo Cash Loan Credit Card State... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:19:46,939 - INFO -  Saved PDF: HDFC_20250812_181946_5176XXXXXXXXXX28_15-01-2024.PDF (163467 bytes)
# 2025-08-12 18:19:46,942 - INFO -  Downloaded: HDFC_20250812_181946_5176XXXXXXXXXX28_15-01-2024.PDF
# 2025-08-12 18:19:46,945 - INFO - Processing email 10/47 (ID: 76616)
# 2025-08-12 18:19:47,447 - INFO -  Processing: Your Account Statement for the month of October 20... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:47,456 - INFO -  Saved PDF: IDFC_20250812_181947_574101XXXX.pdf (166367 bytes)
# 2025-08-12 18:19:47,458 - INFO -  Downloaded: IDFC_20250812_181947_574101XXXX.pdf
# 2025-08-12 18:19:47,461 - INFO - Processing email 11/47 (ID: 77869)
# 2025-08-12 18:19:47,794 - INFO -  Processing: Annual Premium Statement - Steps to download the p... from HDFC Life - noreply <support@hdfclife.com>
# 2025-08-12 18:19:47,798 - INFO - Processing email 12/47 (ID: 69266)
# 2025-08-12 18:19:48,375 - INFO -  Processing: Your Account Statement for the month of February 2... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:48,385 - INFO -  Saved PDF: IDFC_20250812_181948_574101XXXX.pdf (150505 bytes)
# 2025-08-12 18:19:48,388 - INFO -  Downloaded: IDFC_20250812_181948_574101XXXX.pdf
# 2025-08-12 18:19:48,390 - INFO - Processing email 13/47 (ID: 77961)
# 2025-08-12 18:19:48,933 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:19:48,944 - INFO -  Saved PDF: HDFC_20250812_181948_5241XXXXXXXXXX70_15-12-2024.PDF (199616 bytes)
# 2025-08-12 18:19:48,948 - INFO -  Downloaded: HDFC_20250812_181948_5241XXXXXXXXXX70_15-12-2024.PDF
# 2025-08-12 18:19:48,951 - INFO - Processing email 14/47 (ID: 71676)
# 2025-08-12 18:19:49,616 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:19:49,625 - INFO -  Saved PDF: HDFC_20250812_181949_5241XXXXXXXXXX70_15-05-2024.PDF (204231 bytes)
# 2025-08-12 18:19:49,632 - INFO -  Downloaded: HDFC_20250812_181949_5241XXXXXXXXXX70_15-05-2024.PDF
# 2025-08-12 18:19:49,635 - INFO - Processing email 15/47 (ID: 71680)
# 2025-08-12 18:19:50,186 - INFO -  Processing: Your HDFC Bank Insta Jumbo Loan Statement for the ... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:19:50,199 - INFO -  Saved PDF: HDFC_20250812_181950_jumbo_loan_0001019020016143724.pdf (160478 bytes)
# 2025-08-12 18:19:50,203 - INFO -  Downloaded: HDFC_20250812_181950_jumbo_loan_0001019020016143724.pdf
# 2025-08-12 18:19:50,207 - INFO - Processing email 16/47 (ID: 67551)
# 2025-08-12 18:19:50,748 - INFO -  Processing: Your Account Statement for the month of December 2... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:50,757 - INFO -  Saved PDF: IDFC_20250812_181950_574101XXXX.pdf (166137 bytes)
# 2025-08-12 18:19:50,761 - INFO -  Downloaded: IDFC_20250812_181950_574101XXXX.pdf
# 2025-08-12 18:19:50,763 - INFO - Processing email 17/47 (ID: 71262)
# 2025-08-12 18:19:51,415 - INFO -  Processing: Your Account Statement for the month of April 2024... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:51,424 - INFO -  Saved PDF: IDFC_20250812_181951_574101XXXX.pdf (158645 bytes)
# 2025-08-12 18:19:51,428 - INFO -  Downloaded: IDFC_20250812_181951_574101XXXX.pdf
# 2025-08-12 18:19:51,430 - INFO - Processing email 18/47 (ID: 72709)
# 2025-08-12 18:19:52,656 - INFO -  Processing: Your FIRST Power Plus Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:52,678 - INFO -  Saved PDF: IDFC_20250812_181952_90300001872873_20062024_121340426.pdf (855234 bytes)
# 2025-08-12 18:19:52,683 - INFO -  Downloaded: IDFC_20250812_181952_90300001872873_20062024_121340426.pdf
# 2025-08-12 18:19:52,687 - INFO - Processing email 19/47 (ID: 72123)
# 2025-08-12 18:19:53,221 - INFO -  Processing: Your Account Statement for the month of May 2024... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:53,231 - INFO -  Saved PDF: IDFC_20250812_181953_574101XXXX.pdf (157208 bytes)
# 2025-08-12 18:19:53,233 - INFO -  Downloaded: IDFC_20250812_181953_574101XXXX.pdf
# 2025-08-12 18:19:53,237 - INFO - Processing email 20/47 (ID: 76077)
# 2025-08-12 18:19:54,097 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:19:54,110 - INFO -  Saved PDF: HDFC_20250812_181954_5241XXXXXXXXXX70_15-10-2024.PDF (201651 bytes)
# 2025-08-12 18:19:54,113 - INFO -  Downloaded: HDFC_20250812_181954_5241XXXXXXXXXX70_15-10-2024.PDF
# 2025-08-12 18:19:54,116 - INFO - Processing email 21/47 (ID: 73030)
# 2025-08-12 18:19:54,729 - INFO -  Processing: Your Account Statement for the month of June 2024... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:54,741 - INFO -  Saved PDF: IDFC_20250812_181954_574101XXXX.pdf (158322 bytes)
# 2025-08-12 18:19:54,746 - INFO -  Downloaded: IDFC_20250812_181954_574101XXXX.pdf
# 2025-08-12 18:19:54,749 - INFO - Processing email 22/47 (ID: 77263)
# 2025-08-12 18:19:55,762 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:55,776 - INFO -  Saved PDF: IDFC_20250812_181955_20000002170120_22112024_115953132.pdf (431288 bytes)
# 2025-08-12 18:19:55,781 - INFO -  Downloaded: IDFC_20250812_181955_20000002170120_22112024_115953132.pdf
# 2025-08-12 18:19:55,789 - INFO - Processing email 23/47 (ID: 75651)
# 2025-08-12 18:19:56,333 - INFO -  Processing: Your Account Statement for the month of September ... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:56,344 - INFO -  Saved PDF: IDFC_20250812_181956_574101XXXX.pdf (169101 bytes)
# 2025-08-12 18:19:56,347 - INFO -  Downloaded: IDFC_20250812_181956_574101XXXX.pdf
# 2025-08-12 18:19:56,349 - INFO - Processing email 24/47 (ID: 73605)
# 2025-08-12 18:19:57,681 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:57,704 - INFO -  Saved PDF: IDFC_20250812_181957_20000002170120_22072024_124512347.pdf (1003030 bytes)
# 2025-08-12 18:19:57,709 - INFO -  Downloaded: IDFC_20250812_181957_20000002170120_22072024_124512347.pdf
# 2025-08-12 18:19:57,712 - INFO - Processing email 25/47 (ID: 68818)
# 2025-08-12 18:19:58,409 - INFO -  Processing: Your HDFC Bank - Jumbo Cash Loan Credit Card State... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:19:58,419 - INFO -  Saved PDF: HDFC_20250812_181958_5176XXXXXXXXXX28_15-02-2024.PDF (163450 bytes)
# 2025-08-12 18:19:58,425 - INFO -  Downloaded: HDFC_20250812_181958_5176XXXXXXXXXX28_15-02-2024.PDF
# 2025-08-12 18:19:58,428 - INFO - Processing email 26/47 (ID: 75202)
# 2025-08-12 18:19:58,992 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:19:59,000 - INFO -  Saved PDF: HDFC_20250812_181958_5241XXXXXXXXXX70_15-09-2024.PDF (204254 bytes)
# 2025-08-12 18:19:59,003 - INFO -  Downloaded: HDFC_20250812_181958_5241XXXXXXXXXX70_15-09-2024.PDF
# 2025-08-12 18:19:59,007 - INFO - Processing email 27/47 (ID: 68389)
# 2025-08-12 18:19:59,511 - INFO -  Processing: Your Account Statement for the month of January 20... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:19:59,520 - INFO -  Saved PDF: IDFC_20250812_181959_574101XXXX.pdf (146380 bytes)
# 2025-08-12 18:19:59,525 - INFO -  Downloaded: IDFC_20250812_181959_574101XXXX.pdf
# 2025-08-12 18:19:59,529 - INFO - Processing email 28/47 (ID: 74527)
# 2025-08-12 18:20:00,768 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:00,798 - INFO -  Saved PDF: IDFC_20250812_182000_20000002170120_22082024_102741141.pdf (999836 bytes)
# 2025-08-12 18:20:00,803 - INFO -  Downloaded: IDFC_20250812_182000_20000002170120_22082024_102741141.pdf
# 2025-08-12 18:20:00,807 - INFO - Processing email 29/47 (ID: 73407)
# 2025-08-12 18:20:01,394 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:01,411 - INFO -  Saved PDF: HDFC_20250812_182001_5241XXXXXXXXXX70_15-07-2024.PDF (201114 bytes)
# 2025-08-12 18:20:01,415 - INFO -  Downloaded: HDFC_20250812_182001_5241XXXXXXXXXX70_15-07-2024.PDF
# 2025-08-12 18:20:01,425 - INFO - Processing email 30/47 (ID: 70072)
# 2025-08-12 18:20:02,692 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:02,715 - INFO -  Saved PDF: IDFC_20250812_182002_20000002170120_22032024_120254649.pdf (944005 bytes)
# 2025-08-12 18:20:02,717 - INFO -  Downloaded: IDFC_20250812_182002_20000002170120_22032024_120254649.pdf
# 2025-08-12 18:20:02,727 - INFO - Processing email 31/47 (ID: 70344)
# 2025-08-12 18:20:03,265 - INFO -  Processing: Your Account Statement for the month of March 2024... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:03,275 - INFO -  Saved PDF: IDFC_20250812_182003_574101XXXX.pdf (158418 bytes)
# 2025-08-12 18:20:03,280 - INFO -  Downloaded: IDFC_20250812_182003_574101XXXX.pdf
# 2025-08-12 18:20:03,284 - INFO - Processing email 32/47 (ID: 70984)
# 2025-08-12 18:20:04,485 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:04,504 - INFO -  Saved PDF: IDFC_20250812_182004_20000002170120_22042024_114805953.pdf (911608 bytes)
# 2025-08-12 18:20:04,509 - INFO -  Downloaded: IDFC_20250812_182004_20000002170120_22042024_114805953.pdf
# 2025-08-12 18:20:04,512 - INFO - Processing email 33/47 (ID: 75406)
# 2025-08-12 18:20:05,478 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:05,492 - INFO -  Saved PDF: IDFC_20250812_182005_20000002170120_22092024_103642725.pdf (554720 bytes)
# 2025-08-12 18:20:05,494 - INFO -  Downloaded: IDFC_20250812_182005_20000002170120_22092024_103642725.pdf
# 2025-08-12 18:20:05,495 - INFO - Processing email 34/47 (ID: 72591)
# 2025-08-12 18:20:06,096 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:06,116 - INFO -  Saved PDF: HDFC_20250812_182006_5241XXXXXXXXXX70_15-06-2024.PDF (201506 bytes)
# 2025-08-12 18:20:06,119 - INFO -  Downloaded: HDFC_20250812_182006_5241XXXXXXXXXX70_15-06-2024.PDF
# 2025-08-12 18:20:06,126 - INFO - Processing email 35/47 (ID: 75333)
# 2025-08-12 18:20:07,161 - INFO -  Processing: Your FIRST Power Plus Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:07,188 - INFO -  Saved PDF: IDFC_20250812_182007_90300001872873_20092024_104842468.pdf (790494 bytes)
# 2025-08-12 18:20:07,193 - INFO -  Downloaded: IDFC_20250812_182007_90300001872873_20092024_104842468.pdf
# 2025-08-12 18:20:07,197 - INFO - Processing email 36/47 (ID: 73546)
# 2025-08-12 18:20:08,288 - INFO -  Processing: Your FIRST Power Plus Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:08,306 - INFO -  Saved PDF: IDFC_20250812_182008_90300001872873_20072024_113502776.pdf (826858 bytes)
# 2025-08-12 18:20:08,308 - INFO -  Downloaded: IDFC_20250812_182008_90300001872873_20072024_113502776.pdf
# 2025-08-12 18:20:08,310 - INFO - Processing email 37/47 (ID: 68816)
# 2025-08-12 18:20:08,913 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:08,928 - INFO -  Saved PDF: HDFC_20250812_182008_5241XXXXXXXXXX70_15-02-2024.PDF (200624 bytes)
# 2025-08-12 18:20:08,931 - INFO -  Downloaded: HDFC_20250812_182008_5241XXXXXXXXXX70_15-02-2024.PDF
# 2025-08-12 18:20:08,936 - INFO - Processing email 38/47 (ID: 77062)
# 2025-08-12 18:20:09,451 - INFO -  Processing: Your HDFC Bank Insta Jumbo Loan Statement for the ... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:09,459 - INFO -  Saved PDF: HDFC_20250812_182009_jumbo_loan_0001019020020455148.pdf (206038 bytes)
# 2025-08-12 18:20:09,462 - INFO -  Downloaded: HDFC_20250812_182009_jumbo_loan_0001019020020455148.pdf
# 2025-08-12 18:20:09,464 - INFO - Processing email 39/47 (ID: 76281)
# 2025-08-12 18:20:10,316 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:10,330 - INFO -  Saved PDF: IDFC_20250812_182010_20000002170120_22102024_105038793.pdf (432029 bytes)
# 2025-08-12 18:20:10,333 - INFO -  Downloaded: IDFC_20250812_182010_20000002170120_22102024_105038793.pdf
# 2025-08-12 18:20:10,339 - INFO - Processing email 40/47 (ID: 69812)
# 2025-08-12 18:20:10,936 - INFO -  Processing: Your HDFC Bank - Jumbo Cash Loan Credit Card State... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:10,955 - INFO -  Saved PDF: HDFC_20250812_182010_5176XXXXXXXXXX28_15-03-2024.PDF (161013 bytes)
# 2025-08-12 18:20:10,960 - INFO -  Downloaded: HDFC_20250812_182010_5176XXXXXXXXXX28_15-03-2024.PDF
# 2025-08-12 18:20:10,965 - INFO - Processing email 41/47 (ID: 67935)
# 2025-08-12 18:20:11,487 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:11,496 - INFO -  Saved PDF: HDFC_20250812_182011_5241XXXXXXXXXX70_15-01-2024.PDF (203548 bytes)
# 2025-08-12 18:20:11,499 - INFO -  Downloaded: HDFC_20250812_182011_5241XXXXXXXXXX70_15-01-2024.PDF
# 2025-08-12 18:20:11,502 - INFO - Processing email 42/47 (ID: 70754)
# 2025-08-12 18:20:12,115 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:12,132 - INFO -  Saved PDF: HDFC_20250812_182012_5241XXXXXXXXXX70_15-04-2024.PDF (204192 bytes)
# 2025-08-12 18:20:12,139 - INFO -  Downloaded: HDFC_20250812_182012_5241XXXXXXXXXX70_15-04-2024.PDF
# 2025-08-12 18:20:12,145 - INFO - Processing email 43/47 (ID: 74310)
# 2025-08-12 18:20:12,653 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:12,666 - INFO -  Saved PDF: HDFC_20250812_182012_5241XXXXXXXXXX70_15-08-2024.PDF (201105 bytes)
# 2025-08-12 18:20:12,672 - INFO -  Downloaded: HDFC_20250812_182012_5241XXXXXXXXXX70_15-08-2024.PDF
# 2025-08-12 18:20:12,677 - INFO - Processing email 44/47 (ID: 73902)
# 2025-08-12 18:20:13,219 - INFO -  Processing: Your Account Statement for the month of July 2024... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:13,234 - INFO -  Saved PDF: IDFC_20250812_182013_574101XXXX.pdf (164513 bytes)
# 2025-08-12 18:20:13,237 - INFO -  Downloaded: IDFC_20250812_182013_574101XXXX.pdf
# 2025-08-12 18:20:13,240 - INFO - Processing email 45/47 (ID: 74413)
# 2025-08-12 18:20:14,287 - INFO -  Processing: Your FIRST Power Plus Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:14,315 - INFO -  Saved PDF: IDFC_20250812_182014_90300001872873_20082024_132743952.pdf (822254 bytes)
# 2025-08-12 18:20:14,321 - INFO -  Downloaded: IDFC_20250812_182014_90300001872873_20082024_132743952.pdf
# 2025-08-12 18:20:14,328 - INFO - Processing email 46/47 (ID: 71858)
# 2025-08-12 18:20:15,544 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:15,599 - INFO -  Saved PDF: IDFC_20250812_182015_20000002170120_22052024_113042383.pdf (937233 bytes)
# 2025-08-12 18:20:15,603 - INFO -  Downloaded: IDFC_20250812_182015_20000002170120_22052024_113042383.pdf
# 2025-08-12 18:20:15,606 - INFO - Processing email 47/47 (ID: 74771)
# 2025-08-12 18:20:16,131 - INFO -  Processing: Your Account Statement for the month of August 202... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:16,143 - INFO -  Saved PDF: IDFC_20250812_182016_574101XXXX.pdf (164818 bytes)
# 2025-08-12 18:20:16,147 - INFO -  Downloaded: IDFC_20250812_182016_574101XXXX.pdf
# 2025-08-12 18:20:16,165 - INFO -  Done: 47 emails, 46 PDFs.
# 2025-08-12 18:20:16,711 - INFO -  Email connection closed
#  46 PDFs downloaded for 2024
# 2025-08-12 18:20:19,717 - INFO -  Fetching Credit Card Emails from 01-Jan-2023 to 01-Jan-2024
#  Processing Year: 2023
# Searching from 01-Jan-2023 to 01-Jan-2024...
# 2025-08-12 18:20:20,982 - INFO -  Successfully connected to email server
# 2025-08-12 18:20:21,452 - INFO - Searching emails from 01-Jan-2023 to 31-Dec-2023
# 2025-08-12 18:20:22,096 - INFO - Found 22 emails with criteria: (FROM "Emailstatements.cards@hdfcbank.net" SINCE "01-Jan-2023" BEFORE "31-Dec-2023")
# 2025-08-12 18:20:23,076 - INFO - Found 22 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2023" BEFORE "31-Dec-2023") (FROM "hdfc")
# 2025-08-12 18:20:23,370 - INFO - Found 25 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2023" BEFORE "31-Dec-2023") (FROM "idfc")
# 2025-08-12 18:20:23,372 - INFO -  Processing 47 emails for PDF attachments...
# 2025-08-12 18:20:23,374 - INFO - Processing email 1/47 (ID: 57765)
# 2025-08-12 18:20:24,264 - INFO -  Processing: Your Account Statement for the month of December 2... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:24,279 - INFO -  Saved PDF: IDFC_20250812_182024_574101XXXX.pdf (147877 bytes)
# 2025-08-12 18:20:24,283 - INFO -  Downloaded: IDFC_20250812_182024_574101XXXX.pdf
# 2025-08-12 18:20:24,289 - INFO - Processing email 2/47 (ID: 58663)
# 2025-08-12 18:20:24,893 - INFO -  Processing: Your Account Statement for the month of February 2... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:24,905 - INFO -  Saved PDF: IDFC_20250812_182024_574101XXXX.pdf (153734 bytes)
# 2025-08-12 18:20:24,907 - INFO -  Downloaded: IDFC_20250812_182024_574101XXXX.pdf
# 2025-08-12 18:20:24,912 - INFO - Processing email 3/47 (ID: 58831)
# 2025-08-12 18:20:25,494 - INFO -  Processing: Your HDFC Bank - Jumbo Cash Loan Credit Card State... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:25,506 - INFO -  Saved PDF: HDFC_20250812_182025_5176XXXXXXXXXX28_15-03-2023.PDF (162476 bytes)
# 2025-08-12 18:20:25,510 - INFO -  Downloaded: HDFC_20250812_182025_5176XXXXXXXXXX28_15-03-2023.PDF
# 2025-08-12 18:20:25,515 - INFO - Processing email 4/47 (ID: 62275)
# 2025-08-12 18:20:26,261 - INFO -  Processing: Your HDFC Bank - Jumbo Cash Loan Credit Card State... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:26,272 - INFO -  Saved PDF: HDFC_20250812_182026_5176XXXXXXXXXX28_15-07-2023.PDF (161775 bytes)
# 2025-08-12 18:20:26,276 - INFO -  Downloaded: HDFC_20250812_182026_5176XXXXXXXXXX28_15-07-2023.PDF
# 2025-08-12 18:20:26,287 - INFO - Processing email 5/47 (ID: 58370)
# 2025-08-12 18:20:26,906 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:26,922 - INFO -  Saved PDF: HDFC_20250812_182026_5241XXXXXXXXXX70_15-02-2023.PDF (202008 bytes)
# 2025-08-12 18:20:26,925 - INFO -  Downloaded: HDFC_20250812_182026_5241XXXXXXXXXX70_15-02-2023.PDF
# 2025-08-12 18:20:26,927 - INFO - Processing email 6/47 (ID: 60871)
# 2025-08-12 18:20:27,505 - INFO -  Processing: Your Account Statement for the month of May 2023... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:27,523 - INFO -  Saved PDF: IDFC_20250812_182027_574101XXXX.pdf (148704 bytes)
# 2025-08-12 18:20:27,527 - INFO -  Downloaded: IDFC_20250812_182027_574101XXXX.pdf
# 2025-08-12 18:20:27,533 - INFO - Processing email 7/47 (ID: 62451)
# 2025-08-12 18:20:29,577 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:29,607 - INFO -  Saved PDF: IDFC_20250812_182029_20000002170120_22072023_133518850.pdf (1615882 bytes)
# 2025-08-12 18:20:29,611 - INFO -  Downloaded: IDFC_20250812_182029_20000002170120_22072023_133518850.pdf
# 2025-08-12 18:20:29,621 - INFO - Processing email 8/47 (ID: 63231)
# 2025-08-12 18:20:30,124 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:30,136 - INFO -  Saved PDF: HDFC_20250812_182030_5241XXXXXXXXXX70_15-08-2023.PDF (205597 bytes)
# 2025-08-12 18:20:30,139 - INFO -  Downloaded: HDFC_20250812_182030_5241XXXXXXXXXX70_15-08-2023.PDF
# 2025-08-12 18:20:30,143 - INFO - Processing email 9/47 (ID: 66239)
# 2025-08-12 18:20:30,728 - INFO -  Processing: Your HDFC Bank - Jumbo Cash Loan Credit Card State... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:30,740 - INFO -  Saved PDF: HDFC_20250812_182030_5176XXXXXXXXXX28_15-11-2023.PDF (161351 bytes)
# 2025-08-12 18:20:30,741 - INFO -  Downloaded: HDFC_20250812_182030_5176XXXXXXXXXX28_15-11-2023.PDF
# 2025-08-12 18:20:30,743 - INFO - Processing email 10/47 (ID: 59450)
# 2025-08-12 18:20:31,342 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:31,356 - INFO -  Saved PDF: HDFC_20250812_182031_5241XXXXXXXXXX70_15-04-2023.PDF (206026 bytes)
# 2025-08-12 18:20:31,359 - INFO -  Downloaded: HDFC_20250812_182031_5241XXXXXXXXXX70_15-04-2023.PDF
# 2025-08-12 18:20:31,362 - INFO - Processing email 11/47 (ID: 64791)
# 2025-08-12 18:20:32,165 - INFO -  Processing: Your Account Statement for the month of September ... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:32,176 - INFO -  Saved PDF: IDFC_20250812_182032_574101XXXX.pdf (146561 bytes)
# 2025-08-12 18:20:32,178 - INFO -  Downloaded: IDFC_20250812_182032_574101XXXX.pdf
# 2025-08-12 18:20:32,181 - INFO - Processing email 12/47 (ID: 60265)
# 2025-08-12 18:20:32,857 - INFO -  Processing: Your HDFC Bank - Jumbo Cash Loan Credit Card State... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:32,875 - INFO -  Saved PDF: HDFC_20250812_182032_5176XXXXXXXXXX28_15-05-2023.PDF (161795 bytes)
# 2025-08-12 18:20:32,878 - INFO -  Downloaded: HDFC_20250812_182032_5176XXXXXXXXXX28_15-05-2023.PDF
# 2025-08-12 18:20:32,885 - INFO - Processing email 13/47 (ID: 58829)
# 2025-08-12 18:20:33,546 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:33,558 - INFO -  Saved PDF: HDFC_20250812_182033_5241XXXXXXXXXX70_15-03-2023.PDF (201659 bytes)
# 2025-08-12 18:20:33,564 - INFO -  Downloaded: HDFC_20250812_182033_5241XXXXXXXXXX70_15-03-2023.PDF
# 2025-08-12 18:20:33,568 - INFO - Processing email 14/47 (ID: 65435)
# 2025-08-12 18:20:34,977 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:35,051 - INFO -  Saved PDF: IDFC_20250812_182034_20000002170120_21102023_113435729.pdf (941292 bytes)
# 2025-08-12 18:20:35,056 - INFO -  Downloaded: IDFC_20250812_182034_20000002170120_21102023_113435729.pdf
# 2025-08-12 18:20:35,063 - INFO - Processing email 15/47 (ID: 59175)
# 2025-08-12 18:20:35,595 - INFO -  Processing: Your Account Statement for the month of March 2023... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:35,604 - INFO -  Saved PDF: IDFC_20250812_182035_574101XXXX.pdf (145593 bytes)
# 2025-08-12 18:20:35,606 - INFO -  Downloaded: IDFC_20250812_182035_574101XXXX.pdf
# 2025-08-12 18:20:35,610 - INFO - Processing email 16/47 (ID: 58161)
# 2025-08-12 18:20:36,158 - INFO -  Processing: Your Account Statement for the month of January 20... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:36,167 - INFO -  Saved PDF: IDFC_20250812_182036_574101XXXX.pdf (146385 bytes)
# 2025-08-12 18:20:36,170 - INFO -  Downloaded: IDFC_20250812_182036_574101XXXX.pdf
# 2025-08-12 18:20:36,172 - INFO - Processing email 17/47 (ID: 58500)
# 2025-08-12 18:20:38,388 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:38,428 - INFO -  Saved PDF: IDFC_20250812_182038_20000002170120_22022023_140603527.pdf (2128313 bytes)
# 2025-08-12 18:20:38,431 - INFO -  Downloaded: IDFC_20250812_182038_20000002170120_22022023_140603527.pdf
# 2025-08-12 18:20:38,434 - INFO - Processing email 18/47 (ID: 57923)
# 2025-08-12 18:20:38,984 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:38,999 - INFO -  Saved PDF: HDFC_20250812_182038_5241XXXXXXXXXX70_15-01-2023.PDF (198872 bytes)
# 2025-08-12 18:20:39,001 - INFO -  Downloaded: HDFC_20250812_182038_5241XXXXXXXXXX70_15-01-2023.PDF
# 2025-08-12 18:20:39,004 - INFO - Processing email 19/47 (ID: 65203)
# 2025-08-12 18:20:39,706 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:39,717 - INFO -  Saved PDF: HDFC_20250812_182039_5241XXXXXXXXXX70_15-10-2023.PDF (204222 bytes)
# 2025-08-12 18:20:39,721 - INFO -  Downloaded: HDFC_20250812_182039_5241XXXXXXXXXX70_15-10-2023.PDF
# 2025-08-12 18:20:39,724 - INFO - Processing email 20/47 (ID: 67073)
# 2025-08-12 18:20:40,315 - INFO -  Processing: Your HDFC Bank - Jumbo Cash Loan Credit Card State... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:40,331 - INFO -  Saved PDF: HDFC_20250812_182040_5176XXXXXXXXXX28_15-12-2023.PDF (163460 bytes)
# 2025-08-12 18:20:40,335 - INFO -  Downloaded: HDFC_20250812_182040_5176XXXXXXXXXX28_15-12-2023.PDF
# 2025-08-12 18:20:40,337 - INFO - Processing email 21/47 (ID: 59646)
# 2025-08-12 18:20:42,435 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:42,478 - INFO -  Saved PDF: IDFC_20250812_182042_20000002170120_22042023_114958353.pdf (2046572 bytes)
# 2025-08-12 18:20:42,481 - INFO -  Downloaded: IDFC_20250812_182042_20000002170120_22042023_114958353.pdf
# 2025-08-12 18:20:42,482 - INFO - Processing email 22/47 (ID: 64303)
# 2025-08-12 18:20:43,133 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:43,141 - INFO -  Saved PDF: HDFC_20250812_182043_5241XXXXXXXXXX70_15-09-2023.PDF (207877 bytes)
# 2025-08-12 18:20:43,146 - INFO -  Downloaded: HDFC_20250812_182043_5241XXXXXXXXXX70_15-09-2023.PDF
# 2025-08-12 18:20:43,149 - INFO - Processing email 23/47 (ID: 63243)
# 2025-08-12 18:20:43,687 - INFO -  Processing: Your HDFC Bank - Jumbo Cash Loan Credit Card State... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:43,695 - INFO -  Saved PDF: HDFC_20250812_182043_5176XXXXXXXXXX28_15-08-2023.PDF (163463 bytes)
# 2025-08-12 18:20:43,697 - INFO -  Downloaded: HDFC_20250812_182043_5176XXXXXXXXXX28_15-08-2023.PDF
# 2025-08-12 18:20:43,699 - INFO - Processing email 24/47 (ID: 60462)
# 2025-08-12 18:20:45,704 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:45,754 - INFO -  Saved PDF: IDFC_20250812_182045_20000002170120_22052023_135549990.pdf (1913975 bytes)
# 2025-08-12 18:20:45,757 - INFO -  Downloaded: IDFC_20250812_182045_20000002170120_22052023_135549990.pdf
# 2025-08-12 18:20:45,761 - INFO - Processing email 25/47 (ID: 66450)
# 2025-08-12 18:20:47,006 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:47,031 - INFO -  Saved PDF: IDFC_20250812_182047_20000002170120_22112023_114559764.pdf (986120 bytes)
# 2025-08-12 18:20:47,035 - INFO -  Downloaded: IDFC_20250812_182047_20000002170120_22112023_114559764.pdf
# 2025-08-12 18:20:47,039 - INFO - Processing email 26/47 (ID: 67070)
# 2025-08-12 18:20:47,579 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:47,592 - INFO -  Saved PDF: HDFC_20250812_182047_5241XXXXXXXXXX70_15-12-2023.PDF (200517 bytes)
# 2025-08-12 18:20:47,595 - INFO -  Downloaded: HDFC_20250812_182047_5241XXXXXXXXXX70_15-12-2023.PDF
# 2025-08-12 18:20:47,600 - INFO - Processing email 27/47 (ID: 62845)
# 2025-08-12 18:20:48,184 - INFO -  Processing: Your Account Statement for the month of July 2023... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:48,194 - INFO -  Saved PDF: IDFC_20250812_182048_574101XXXX.pdf (160639 bytes)
# 2025-08-12 18:20:48,197 - INFO -  Downloaded: IDFC_20250812_182048_574101XXXX.pdf
# 2025-08-12 18:20:48,200 - INFO - Processing email 28/47 (ID: 64305)
# 2025-08-12 18:20:48,753 - INFO -  Processing: Your HDFC Bank - Jumbo Cash Loan Credit Card State... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:48,761 - INFO -  Saved PDF: HDFC_20250812_182048_5176XXXXXXXXXX28_15-09-2023.PDF (161348 bytes)
# 2025-08-12 18:20:48,765 - INFO -  Downloaded: HDFC_20250812_182048_5176XXXXXXXXXX28_15-09-2023.PDF
# 2025-08-12 18:20:48,767 - INFO - Processing email 29/47 (ID: 62274)
# 2025-08-12 18:20:49,288 - INFO -  Processing: Your HDFC Bank - Titanium Times Card Credit Card S... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:49,297 - INFO -  Saved PDF: HDFC_20250812_182049_5241XXXXXXXXXX70_15-07-2023.PDF (203362 bytes)
# 2025-08-12 18:20:49,299 - INFO -  Downloaded: HDFC_20250812_182049_5241XXXXXXXXXX70_15-07-2023.PDF
# 2025-08-12 18:20:49,301 - INFO - Processing email 30/47 (ID: 67284)
# 2025-08-12 18:20:50,684 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:50,705 - INFO -  Saved PDF: IDFC_20250812_182050_20000002170120_22122023_101710414.pdf (1014708 bytes)
# 2025-08-12 18:20:50,710 - INFO -  Downloaded: IDFC_20250812_182050_20000002170120_22122023_101710414.pdf
# 2025-08-12 18:20:50,713 - INFO - Processing email 31/47 (ID: 66682)
# 2025-08-12 18:20:51,333 - INFO -  Processing: Your Account Statement for the month of November 2... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:51,346 - INFO -  Saved PDF: IDFC_20250812_182051_574101XXXX.pdf (144875 bytes)
# 2025-08-12 18:20:51,350 - INFO -  Downloaded: IDFC_20250812_182051_574101XXXX.pdf
# 2025-08-12 18:20:51,354 - INFO - Processing email 32/47 (ID: 59947)
# 2025-08-12 18:20:51,860 - INFO -  Processing: Your Account Statement for the month of April 2023... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:51,874 - INFO -  Saved PDF: IDFC_20250812_182051_574101XXXX.pdf (142092 bytes)
# 2025-08-12 18:20:51,878 - INFO -  Downloaded: IDFC_20250812_182051_574101XXXX.pdf
# 2025-08-12 18:20:51,880 - INFO - Processing email 33/47 (ID: 58015)
# 2025-08-12 18:20:54,132 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:54,177 - INFO -  Saved PDF: IDFC_20250812_182054_20000002170120_21012023_190520984.pdf (2344822 bytes)
# 2025-08-12 18:20:54,181 - INFO -  Downloaded: IDFC_20250812_182054_20000002170120_21012023_190520984.pdf
# 2025-08-12 18:20:54,183 - INFO - Processing email 34/47 (ID: 58949)
# 2025-08-12 18:20:56,569 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:56,661 - INFO -  Saved PDF: IDFC_20250812_182056_20000002170120_22032023_153026987.pdf (2045618 bytes)
# 2025-08-12 18:20:56,666 - INFO -  Downloaded: IDFC_20250812_182056_20000002170120_22032023_153026987.pdf
# 2025-08-12 18:20:56,669 - INFO - Processing email 35/47 (ID: 61455)
# 2025-08-12 18:20:58,797 - INFO -  Processing: Your FIRST Millennia Credit Card Statement... from IDFC FIRST Bank <statement@idfcfirstbank.com>
# 2025-08-12 18:20:58,837 - INFO -  Saved PDF: IDFC_20250812_182058_20000002170120_22062023_121719205.pdf (1895371 bytes)
# 2025-08-12 18:20:58,841 - INFO -  Downloaded: IDFC_20250812_182058_20000002170120_22062023_121719205.pdf
# 2025-08-12 18:20:58,856 - INFO - Processing email 36/47 (ID: 61213)
# 2025-08-12 18:20:59,406 - INFO -  Processing: Your HDFC Bank - Jumbo Cash Loan Credit Card State... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# 2025-08-12 18:20:59,419 - INFO -  Saved PDF: HDFC_20250812_182059_5176XXXXXXXXXX28_15-06-2023.PDF (161782 bytes)
# 2025-08-12 18:20:59,424 - INFO -  Downloaded: HDFC_20250812_182059_5176XXXXXXXXXX28_15-06-2023.PDF
# 2025-08-12 18:20:59,427 - INFO - Processing email 37/47 (ID: 59453)
# 2025-08-12 18:20:59,915 - INFO -  Processing: Your HDFC Bank - Jumbo Cash Loan Credit Card State... from HDFC Bank Credit Cards <Emailstatements.cards@hdfcbank.net>
# ...
# 2025-08-12 18:22:44,414 - INFO -  Downloaded: HDFC_20250812_182244_5010XXXXXX3726_74476e92_22Jun2019_TO_21Jul2019_010145121.pdf
# 2025-08-12 18:22:44,416 - INFO - Processing email 7/12 (ID: 33076)
# 2025-08-12 18:22:44,801 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:22:44,807 - INFO - Processing email 8/12 (ID: 26712)
# 2025-08-12 18:22:45,380 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:22:45,389 - INFO -  Saved PDF: HDFC_20250812_182245_5010XXXXXX3726_724a9ca6_22May2019_TO_21Jun2019_032455110.pdf (29243 bytes)
# 2025-08-12 18:22:45,393 - INFO -  Downloaded: HDFC_20250812_182245_5010XXXXXX3726_724a9ca6_22May2019_TO_21Jun2019_032455110.pdf
# 2025-08-12 18:22:45,397 - INFO - Processing email 9/12 (ID: 32130)
# 2025-08-12 18:22:45,724 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:22:45,726 - INFO - Processing email 10/12 (ID: 29974)
# 2025-08-12 18:22:46,142 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:22:46,144 - INFO - Processing email 11/12 (ID: 23897)
# 2025-08-12 18:22:46,774 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:22:46,784 - INFO -  Saved PDF: HDFC_20250812_182246_5010XXXXXX3726_3f410585_22Feb2019_TO_21Mar2019_021809678.pdf (28346 bytes)
# 2025-08-12 18:22:46,789 - INFO -  Downloaded: HDFC_20250812_182246_5010XXXXXX3726_3f410585_22Feb2019_TO_21Mar2019_021809678.pdf
# 2025-08-12 18:22:46,793 - INFO - Processing email 12/12 (ID: 25750)
# 2025-08-12 18:22:47,455 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:22:47,464 - INFO -  Saved PDF: HDFC_20250812_182247_5010XXXXXX3726_d940439a_22Apr2019_TO_21May2019_045541684.pdf (27885 bytes)
# 2025-08-12 18:22:47,469 - INFO -  Downloaded: HDFC_20250812_182247_5010XXXXXX3726_d940439a_22Apr2019_TO_21May2019_045541684.pdf
# 2025-08-12 18:22:47,478 - INFO -  Done: 12 emails, 8 PDFs.
# 2025-08-12 18:22:48,153 - INFO -  Email connection closed
#  8 PDFs downloaded for 2019
# 2025-08-12 18:22:51,158 - INFO -  Fetching Credit Card Emails from 01-Jan-2018 to 01-Jan-2019
#  Processing Year: 2018
# Searching from 01-Jan-2018 to 01-Jan-2019...
# 2025-08-12 18:22:52,432 - INFO -  Successfully connected to email server
# 2025-08-12 18:22:52,930 - INFO - Searching emails from 01-Jan-2018 to 31-Dec-2018
# 2025-08-12 18:22:54,421 - INFO - Found 10 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2018" BEFORE "31-Dec-2018") (FROM "hdfc")
# 2025-08-12 18:22:54,790 - INFO -  Processing 10 emails for PDF attachments...
# 2025-08-12 18:22:54,792 - INFO - Processing email 1/10 (ID: 13633)
# 2025-08-12 18:22:55,837 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:22:55,844 - INFO -  Saved PDF: HDFC_20250812_182255_5010XXXXXX5641_27744628_23Dec2017_TO_22Jan2018_061323957.pdf (22315 bytes)
# 2025-08-12 18:22:55,849 - INFO -  Downloaded: HDFC_20250812_182255_5010XXXXXX5641_27744628_23Dec2017_TO_22Jan2018_061323957.pdf
# 2025-08-12 18:22:55,853 - INFO - Processing email 2/10 (ID: 16063)
# 2025-08-12 18:22:56,378 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:22:56,386 - INFO -  Saved PDF: HDFC_20250812_182256_5010XXXXXX5641_a4b9788a_23Apr2018_TO_22May2018_044120810.pdf (21775 bytes)
# 2025-08-12 18:22:56,389 - INFO -  Downloaded: HDFC_20250812_182256_5010XXXXXX5641_a4b9788a_23Apr2018_TO_22May2018_044120810.pdf
# 2025-08-12 18:22:56,391 - INFO - Processing email 3/10 (ID: 17133)
# 2025-08-12 18:22:57,008 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:22:57,014 - INFO -  Saved PDF: HDFC_20250812_182257_5010XXXXXX5641_16e4923b_23Jun2018_TO_22Jul2018_233751475.pdf (21772 bytes)
# 2025-08-12 18:22:57,017 - INFO -  Downloaded: HDFC_20250812_182257_5010XXXXXX5641_16e4923b_23Jun2018_TO_22Jul2018_233751475.pdf
# 2025-08-12 18:22:57,020 - INFO - Processing email 4/10 (ID: 17951)
# 2025-08-12 18:22:57,842 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:22:57,849 - INFO -  Saved PDF: HDFC_20250812_182257_5010XXXXXX5641_25473494_23Jul2018_TO_22Aug2018_022111570.pdf (21771 bytes)
# 2025-08-12 18:22:57,854 - INFO -  Downloaded: HDFC_20250812_182257_5010XXXXXX5641_25473494_23Jul2018_TO_22Aug2018_022111570.pdf
# 2025-08-12 18:22:57,857 - INFO - Processing email 5/10 (ID: 15448)
# 2025-08-12 18:22:58,713 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:22:58,722 - INFO -  Saved PDF: HDFC_20250812_182258_5010XXXXXX5641_34ae38a0_23Mar2018_TO_22Apr2018_003133278.pdf (21774 bytes)
# 2025-08-12 18:22:58,725 - INFO -  Downloaded: HDFC_20250812_182258_5010XXXXXX5641_34ae38a0_23Mar2018_TO_22Apr2018_003133278.pdf
# 2025-08-12 18:22:58,728 - INFO - Processing email 6/10 (ID: 18500)
# 2025-08-12 18:22:59,304 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:22:59,311 - INFO -  Saved PDF: HDFC_20250812_182259_5010XXXXXX5641_4c5f8f92_22Aug2018_TO_10Sep2018_040212898.pdf (21772 bytes)
# 2025-08-12 18:22:59,314 - INFO -  Downloaded: HDFC_20250812_182259_5010XXXXXX5641_4c5f8f92_22Aug2018_TO_10Sep2018_040212898.pdf
# 2025-08-12 18:22:59,321 - INFO - Processing email 7/10 (ID: 14861)
# 2025-08-12 18:22:59,856 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:22:59,861 - INFO -  Saved PDF: HDFC_20250812_182259_5010XXXXXX5641_e844988a_23Feb2018_TO_22Mar2018_053829448.pdf (21694 bytes)
# 2025-08-12 18:22:59,863 - INFO -  Downloaded: HDFC_20250812_182259_5010XXXXXX5641_e844988a_23Feb2018_TO_22Mar2018_053829448.pdf
# 2025-08-12 18:22:59,866 - INFO - Processing email 8/10 (ID: 16602)
# 2025-08-12 18:23:00,491 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:23:00,500 - INFO -  Saved PDF: HDFC_20250812_182300_5010XXXXXX5641_8242bd9a_23May2018_TO_22Jun2018_044537118.pdf (21772 bytes)
# 2025-08-12 18:23:00,504 - INFO -  Downloaded: HDFC_20250812_182300_5010XXXXXX5641_8242bd9a_23May2018_TO_22Jun2018_044537118.pdf
# 2025-08-12 18:23:00,509 - INFO - Processing email 9/10 (ID: 21192)
# 2025-08-12 18:23:00,969 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:23:00,976 - INFO -  Saved PDF: HDFC_20250812_182300_5010XXXXXX3726_22435f85_22Nov2018_TO_21Dec2018_194251940.pdf (23823 bytes)
# 2025-08-12 18:23:00,979 - INFO -  Downloaded: HDFC_20250812_182300_5010XXXXXX3726_22435f85_22Nov2018_TO_21Dec2018_194251940.pdf
# 2025-08-12 18:23:00,984 - INFO - Processing email 10/10 (ID: 14430)
# 2025-08-12 18:23:01,582 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:23:01,590 - INFO -  Saved PDF: HDFC_20250812_182301_5010XXXXXX5641_f949a6a8_23Jan2018_TO_22Feb2018_042040929.pdf (21695 bytes)
# 2025-08-12 18:23:01,594 - INFO -  Downloaded: HDFC_20250812_182301_5010XXXXXX5641_f949a6a8_23Jan2018_TO_22Feb2018_042040929.pdf
# 2025-08-12 18:23:01,602 - INFO -  Done: 10 emails, 10 PDFs.
# 2025-08-12 18:23:02,189 - INFO -  Email connection closed
#  10 PDFs downloaded for 2018
# 2025-08-12 18:23:05,191 - INFO -  Fetching Credit Card Emails from 01-Jan-2017 to 01-Jan-2018
#  Processing Year: 2017
# Searching from 01-Jan-2017 to 01-Jan-2018...
# 2025-08-12 18:23:06,404 - INFO -  Successfully connected to email server
# 2025-08-12 18:23:06,877 - INFO - Searching emails from 01-Jan-2017 to 31-Dec-2017
# 2025-08-12 18:23:08,392 - INFO - Found 10 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2017" BEFORE "31-Dec-2017") (FROM "hdfc")
# 2025-08-12 18:23:08,685 - INFO -  Processing 10 emails for PDF attachments...
# 2025-08-12 18:23:08,687 - INFO - Processing email 1/10 (ID: 11505)
# 2025-08-12 18:23:09,243 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:23:09,252 - INFO -  Saved PDF: HDFC_20250812_182309_5010XXXXXX5641_d48919df_23Sep2017_TO_22Oct2017_005657563.pdf (28343 bytes)
# 2025-08-12 18:23:09,254 - INFO -  Downloaded: HDFC_20250812_182309_5010XXXXXX5641_d48919df_23Sep2017_TO_22Oct2017_005657563.pdf
# 2025-08-12 18:23:09,258 - INFO - Processing email 2/10 (ID: 10961)
# 2025-08-12 18:23:09,734 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:23:09,745 - INFO -  Saved PDF: HDFC_20250812_182309_5010XXXXXX5641_24f95a3e_23Aug2017_TO_22Sep2017_094054180.pdf (28037 bytes)
# 2025-08-12 18:23:09,749 - INFO -  Downloaded: HDFC_20250812_182309_5010XXXXXX5641_24f95a3e_23Aug2017_TO_22Sep2017_094054180.pdf
# 2025-08-12 18:23:09,754 - INFO - Processing email 3/10 (ID: 10400)
# 2025-08-12 18:23:10,186 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:23:10,195 - INFO -  Saved PDF: HDFC_20250812_182310_5010XXXXXX5641_421eac1e_23Jul2017_TO_22Aug2017_060957682.pdf (21689 bytes)
# 2025-08-12 18:23:10,198 - INFO -  Downloaded: HDFC_20250812_182310_5010XXXXXX5641_421eac1e_23Jul2017_TO_22Aug2017_060957682.pdf
# 2025-08-12 18:23:10,203 - INFO - Processing email 4/10 (ID: 9363)
# 2025-08-12 18:23:10,782 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:23:10,791 - INFO -  Saved PDF: HDFC_20250812_182310_5010XXXXXX5641_b49f0b91_23May2017_TO_22Jun2017_045645622.pdf (23613 bytes)
# 2025-08-12 18:23:10,794 - INFO -  Downloaded: HDFC_20250812_182310_5010XXXXXX5641_b49f0b91_23May2017_TO_22Jun2017_045645622.pdf
# 2025-08-12 18:23:10,797 - INFO - Processing email 5/10 (ID: 9871)
# 2025-08-12 18:23:11,316 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from HDFC Bank Smart Statement <hdfcbanksmartstatement@hdfcbank.net>
# 2025-08-12 18:23:11,326 - INFO -  Saved PDF: HDFC_20250812_182311_5010XXXXXX5641_0455c843_23Jun2017_TO_22Jul2017_034915096.pdf (23548 bytes)
# 2025-08-12 18:23:11,329 - INFO -  Downloaded: HDFC_20250812_182311_5010XXXXXX5641_0455c843_23Jun2017_TO_22Jul2017_034915096.pdf
# 2025-08-12 18:23:11,332 - INFO - Processing email 6/10 (ID: 7442)
# 2025-08-12 18:23:12,026 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from "HDFC Bank CASA Statement"<emailstatements@hdfcbank.net>
# 2025-08-12 18:23:12,036 - INFO -  Saved PDF: HDFC_20250812_182312_5010XXXXXX5641-23-Jan-2017 TO 22-Feb-2017.pdf (130476 bytes)
# 2025-08-12 18:23:12,040 - INFO -  Downloaded: HDFC_20250812_182312_5010XXXXXX5641-23-Jan-2017 TO 22-Feb-2017.pdf
# 2025-08-12 18:23:12,046 - INFO - Processing email 7/10 (ID: 8815)
# 2025-08-12 18:23:12,554 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from "HDFC Bank CASA Statement"<emailstatements@hdfcbank.net>
# 2025-08-12 18:23:12,568 - INFO -  Saved PDF: HDFC_20250812_182312_5010XXXXXX5641-23-Apr-2017 TO 22-May-2017.pdf (103369 bytes)
# 2025-08-12 18:23:12,572 - INFO -  Downloaded: HDFC_20250812_182312_5010XXXXXX5641-23-Apr-2017 TO 22-May-2017.pdf
# 2025-08-12 18:23:12,576 - INFO - Processing email 8/10 (ID: 8380)
# 2025-08-12 18:23:13,095 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from "HDFC Bank CASA Statement"<emailstatements@hdfcbank.net>
# 2025-08-12 18:23:13,103 - INFO -  Saved PDF: HDFC_20250812_182313_5010XXXXXX5641-23-Mar-2017 TO 22-Apr-2017.pdf (104582 bytes)
# 2025-08-12 18:23:13,106 - INFO -  Downloaded: HDFC_20250812_182313_5010XXXXXX5641-23-Mar-2017 TO 22-Apr-2017.pdf
# 2025-08-12 18:23:13,109 - INFO - Processing email 9/10 (ID: 7927)
# 2025-08-12 18:23:13,612 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from "HDFC Bank CASA Statement"<emailstatements@hdfcbank.net>
# 2025-08-12 18:23:13,621 - INFO -  Saved PDF: HDFC_20250812_182313_5010XXXXXX5641-23-Feb-2017 TO 22-Mar-2017.pdf (103553 bytes)
# 2025-08-12 18:23:13,625 - INFO -  Downloaded: HDFC_20250812_182313_5010XXXXXX5641-23-Feb-2017 TO 22-Mar-2017.pdf
# 2025-08-12 18:23:13,627 - INFO - Processing email 10/10 (ID: 6944)
# 2025-08-12 18:23:14,314 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from "HDFC Bank CASA Statement"<emailstatements@hdfcbank.net>
# 2025-08-12 18:23:14,326 - INFO -  Saved PDF: HDFC_20250812_182314_5010XXXXXX5641-23-Dec-2016 TO 22-Jan-2017.pdf (129219 bytes)
# 2025-08-12 18:23:14,329 - INFO -  Downloaded: HDFC_20250812_182314_5010XXXXXX5641-23-Dec-2016 TO 22-Jan-2017.pdf
# 2025-08-12 18:23:14,338 - INFO -  Done: 10 emails, 10 PDFs.
# 2025-08-12 18:23:14,920 - INFO -  Email connection closed
#  10 PDFs downloaded for 2017
# 2025-08-12 18:23:17,926 - INFO -  Fetching Credit Card Emails from 01-Jan-2016 to 01-Jan-2017
#  Processing Year: 2016
# Searching from 01-Jan-2016 to 01-Jan-2017...
# 2025-08-12 18:23:19,153 - INFO -  Successfully connected to email server
# 2025-08-12 18:23:19,674 - INFO - Searching emails from 01-Jan-2016 to 31-Dec-2016
# 2025-08-12 18:23:21,139 - INFO - Found 2 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2016" BEFORE "31-Dec-2016") (FROM "hdfc")
# 2025-08-12 18:23:21,428 - INFO -  Processing 2 emails for PDF attachments...
# 2025-08-12 18:23:21,432 - INFO - Processing email 1/2 (ID: 6174)
# 2025-08-12 18:23:22,420 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from "HDFC Bank CASA Statement"<emailstatements@hdfcbank.net>
# 2025-08-12 18:23:22,429 - INFO -  Saved PDF: HDFC_20250812_182322_5010XXXXXX5641-23-Oct-2016 TO 22-Nov-2016.pdf (128830 bytes)
# 2025-08-12 18:23:22,432 - INFO -  Downloaded: HDFC_20250812_182322_5010XXXXXX5641-23-Oct-2016 TO 22-Nov-2016.pdf
# 2025-08-12 18:23:22,435 - INFO - Processing email 2/2 (ID: 6562)
# 2025-08-12 18:23:22,993 - INFO -  Processing: Email Account Statement of your HDFC Bank Account ... from "HDFC Bank CASA Statement"<emailstatements@hdfcbank.net>
# 2025-08-12 18:23:23,005 - INFO -  Saved PDF: HDFC_20250812_182322_5010XXXXXX5641-23-Nov-2016 TO 22-Dec-2016.pdf (128999 bytes)
# 2025-08-12 18:23:23,010 - INFO -  Downloaded: HDFC_20250812_182322_5010XXXXXX5641-23-Nov-2016 TO 22-Dec-2016.pdf
# 2025-08-12 18:23:23,018 - INFO -  Done: 2 emails, 2 PDFs.
# 2025-08-12 18:23:23,553 - INFO -  Email connection closed
#  2 PDFs downloaded for 2016
# 2025-08-12 18:23:26,557 - INFO -  Fetching Credit Card Emails from 01-Jan-2015 to 01-Jan-2016
#  Processing Year: 2015
# Searching from 01-Jan-2015 to 01-Jan-2016...
# 2025-08-12 18:23:27,775 - INFO -  Successfully connected to email server
# 2025-08-12 18:23:28,268 - INFO - Searching emails from 01-Jan-2015 to 31-Dec-2015
# 2025-08-12 18:23:30,026 - INFO -  No emails found in this date range.
# 2025-08-12 18:23:30,551 - INFO -  Email connection closed
#  No emails found for 2015. Stopping search.
# ==================================================
#  All Years Processing Complete!
# Total PDFs downloaded: 195

# %%
# Email Body Content Parser - Phase 2 Alternative Approach
import re
from datetime import datetime
import pandas as pd

def extract_amount_from_email_body(email_body, bank):
    """Extract amount from email body text"""
    # Common amount patterns for both banks
    amount_patterns = [
        r'Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
        r'Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
        r'Amount Payable[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
        r'Outstanding Amount[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
        r'Current Balance[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
        # More flexible patterns
        r'(?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)',
        r'([0-9,]+\.?[0-9]*)\s*(?:Rs\.?|INR|₹)'
    ]
    
    for pattern in amount_patterns:
        matches = re.findall(pattern, email_body, re.IGNORECASE)
        if matches:
            for match in matches:
                try:
                    # Clean and convert amount
                    clean_amount = match.replace(',', '').strip()
                    amount = float(clean_amount)
                    # Reasonable amount range for credit card bills
                    if 100 <= amount <= 500000:  # Between Rs.100 to Rs.5,00,000
                        return amount
                except ValueError:
                    continue
    return None

def extract_due_date_from_email_body(email_body):
    """Extract due date from email body"""
    due_date_patterns = [
        r'Due Date[:\s]*([0-9]{1,2}[/-][0-9]{1,2}[/-][0-9]{4})',
        r'Payment Due Date[:\s]*([0-9]{1,2}[/-][0-9]{1,2}[/-][0-9]{4})',
        r'Pay by[:\s]*([0-9]{1,2}[/-][0-9]{1,2}[/-][0-9]{4})',
        r'due on[:\s]*([0-9]{1,2}[/-][0-9]{1,2}[/-][0-9]{4})'
    ]
    
    for pattern in due_date_patterns:
        matches = re.findall(pattern, email_body, re.IGNORECASE)
        if matches:
            return matches[0]  # Return first match
    return ""

def standardize_date_components(date_str):
    """Convert date to required format components"""
    if not date_str:
        return "", "", ""
    
    try:
        # Try different date formats
        for fmt in ['%d/%m/%Y', '%d-%m-%Y', '%Y/%m/%d', '%Y-%m-%d']:
            try:
                date_obj = datetime.strptime(date_str, fmt)
                return (
                    date_obj.strftime('%d/%m/%Y'),  # DATE
                    date_obj.strftime('%B'),        # MONTH  
                    str(date_obj.year)              # YEAR
                )
            except ValueError:
                continue
                
        # Manual parsing for mixed formats
        if re.match(r'\d{1,2}[/-]\d{1,2}[/-]\d{4}', date_str):
            parts = re.split('[/-]', date_str)
            day, month, year = parts[0], parts[1], parts[2]
            date_obj = datetime(int(year), int(month), int(day))
            return (
                f"{day.zfill(2)}/{month.zfill(2)}/{year}",
                date_obj.strftime('%B'),
                year
            )
    except:
        pass
    
    return date_str, "", ""

def process_email_body_for_data(msg, sender):
    """Process email message to extract required data"""
    try:
        # Get email body text
        email_body = ""
        if msg.is_multipart():
            for part in msg.walk():
                if part.get_content_type() == "text/plain":
                    email_body += part.get_payload(decode=True).decode('utf-8', errors='ignore')
        else:
            email_body = msg.get_payload(decode=True).decode('utf-8', errors='ignore')
        
        # Identify bank
        bank = identify_bank(sender)
        if bank not in ['HDFC', 'IDFC']:
            return None
            
        # Extract amount
        amount = extract_amount_from_email_body(email_body, bank)
        if amount is None:
            return None
            
        # Get email date (received date as statement date)
        email_date = msg.get('Date', '')
        if email_date:
            try:
                # Parse email date
                email_datetime = email.utils.parsedate_to_datetime(email_date)
                statement_date = email_datetime.strftime('%d/%m/%Y')
            except:
                statement_date = datetime.now().strftime('%d/%m/%Y')
        else:
            statement_date = datetime.now().strftime('%d/%m/%Y')
            
        # Extract due date from email body
        due_date = extract_due_date_from_email_body(email_body)
        
        # Standardize statement date components
        date_formatted, month_name, year = standardize_date_components(statement_date)
        
        # Create record
        record = {
            'DATE': date_formatted,
            'MONTH': month_name,
            'YEAR': year, 
            'BANK': bank,
            'AMOUNT': amount,
            'DUE_DATE': due_date,
            'EMAIL_SUBJECT': decode_header_value(msg.get("Subject", "")),
            'PROCESSED_TIME': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        }
        
        return record
        
    except Exception as e:
        logger.error(f"Error processing email body: {e}")
        return None

print(" Email body parsing functions defined successfully!")
# Out:
#  Email body parsing functions defined successfully!

# %%
def create_excel_from_email_data(records, output_path):
    """Create Excel file from email body extracted data"""
    if not records:
        print(" No data to export to Excel")
        return False
        
    try:
        # Create DataFrame
        df = pd.DataFrame(records)
        
        # Ensure output directory exists
        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        
        # Create Excel with multiple sheets
        with pd.ExcelWriter(output_path, engine='openpyxl') as writer:
            # Main data sheet - your required columns first
            main_columns = ['DATE', 'MONTH', 'YEAR', 'BANK', 'AMOUNT', 'DUE_DATE']
            df_main = df[main_columns + ['EMAIL_SUBJECT', 'PROCESSED_TIME']]
            df_main.to_excel(writer, sheet_name='Credit Card Data', index=False)
            
            # Summary by bank and year
            summary = df.groupby(['BANK', 'YEAR']).agg({
                'AMOUNT': ['sum', 'count', 'mean']
            }).round(2)
            summary.columns = ['Total_Amount', 'Count', 'Average_Amount']
            summary.to_excel(writer, sheet_name='Bank Year Summary')
            
            # Monthly summary
            monthly = df.groupby(['YEAR', 'MONTH', 'BANK'])['AMOUNT'].sum().reset_index()
            monthly.to_excel(writer, sheet_name='Monthly Summary', index=False)
        
        # Display results
        total_amount = df['AMOUNT'].sum()
        print(f"EXCEL FILE CREATED SUCCESSFULLY!")
        print(f"Location: {output_path}")
        print(f" Total Records: {len(df)}")
        print(f"Banks: {', '.join(df['BANK'].unique())}")
        print(f" Total Amount: ₹{total_amount:,.2f}")
        print(f" Date Range: {df['DATE'].min()} to {df['DATE'].max()}")
        
        return True
        
    except Exception as e:
        print(f" Error creating Excel file: {e}")
        return False

print(" Excel output function defined successfully!")
# Out:
#  Excel output function defined successfully!

# %%
# IMPROVED Email Body Content Parser - Phase 2 Alternative Approach
import re
from datetime import datetime
import pandas as pd
from html import unescape

def clean_html_content(html_text):
    """Clean HTML content and extract readable text"""
    if not html_text:
        return ""
    
    # Remove HTML tags
    text = re.sub(r'<[^>]+>', ' ', html_text)
    
    # Decode HTML entities
    text = unescape(text)
    
    # Clean up extra spaces and newlines
    text = re.sub(r'\s+', ' ', text)
    
    # Remove CSS and JavaScript content
    text = re.sub(r'\.[\w\-]+\s*\{[^}]*\}', ' ', text)  # CSS
    text = re.sub(r'function\s*\([^}]*\}', ' ', text)   # JavaScript
    
    return text.strip()

def extract_amount_from_email_body(email_body, bank):
    """Extract amount from email body text - IMPROVED"""
    # Clean HTML first
    clean_body = clean_html_content(email_body)
    
    # IDFC specific patterns (more comprehensive)
    idfc_patterns = [
        r'Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
        r'Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
        r'Amount Payable[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
        r'Outstanding[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
        r'Current Balance[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
        # Try reverse patterns
        r'(?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)',
        # Look for numbers followed by currency in various contexts
        r'([0-9,]+\.?[0-9]*)\s*(?:Rs\.?|INR|₹)',
        # More flexible patterns
        r'\b([0-9,]+\.[0-9]{2})\b',  # Any number with 2 decimal places
        r'\b([1-9][0-9,]{2,})\b'     # Numbers with 3+ digits
    ]
    
    # HDFC specific patterns 
    hdfc_patterns = [
        r'Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
        r'Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
        r'Outstanding Balance[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
        r'Current Outstanding[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
        r'(?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)',
        r'([0-9,]+\.?[0-9]*)\s*(?:Rs\.?|INR|₹)',
        r'\b([0-9,]+\.[0-9]{2})\b',
        r'\b([1-9][0-9,]{2,})\b'
    ]
    
    # Choose patterns based on bank
    patterns = idfc_patterns if bank == 'IDFC' else hdfc_patterns
    
    # Try patterns on both original and cleaned content
    for content in [clean_body, email_body]:
        for pattern in patterns:
            matches = re.findall(pattern, content, re.IGNORECASE)
            if matches:
                for match in matches:
                    try:
                        # Clean and convert amount
                        clean_amount = match.replace(',', '').strip()
                        amount = float(clean_amount)
                        # Reasonable amount range (₹50 to ₹10,00,000)
                        if 50 <= amount <= 1000000:
                            print(f"    Found amount: ₹{amount} using pattern: {pattern[:50]}...")
                            return amount
                    except ValueError:
                        continue
    
    print(f"    No valid amount found for {bank}")
    return None

def extract_due_date_from_email_body(email_body):
    """Extract due date from email body - IMPROVED"""
    clean_body = clean_html_content(email_body)
    
    # Due date patterns - more comprehensive
    due_date_patterns = [
        r'Due Date[:\s]*([0-9]{1,2}[/-][0-9]{1,2}[/-][0-9]{4})',
        r'Payment Due Date[:\s]*([0-9]{1,2}[/-][0-9]{1,2}[/-][0-9]{4})',
        r'Pay by[:\s]*([0-9]{1,2}[/-][0-9]{1,2}[/-][0-9]{4})',
        r'due on[:\s]*([0-9]{1,2}[/-][0-9]{1,2}[/-][0-9]{4})',
        r'Payment date[:\s]*([0-9]{1,2}[/-][0-9]{1,2}[/-][0-9]{4})',
        r'Last date[:\s]*([0-9]{1,2}[/-][0-9]{1,2}[/-][0-9]{4})',
        # Different date formats
        r'([0-9]{1,2}[/-][0-9]{1,2}[/-][0-9]{4})',  # Any date pattern
        # Month name formats
        r'([0-9]{1,2}\s+(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*\s+[0-9]{4})',
        r'((?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*\s+[0-9]{1,2},?\s+[0-9]{4})'
    ]
    
    # Try patterns on both cleaned and original content
    for content in [clean_body, email_body]:
        for pattern in due_date_patterns:
            matches = re.findall(pattern, content, re.IGNORECASE)
            if matches:
                # Return first reasonable match
                for match in matches:
                    if len(match) >= 8:  # Minimum reasonable date length
                        print(f"    Found due date: {match}")
                        return match
    
    print("    No due date found")
    return ""

def process_email_body_for_data(msg, sender):
    """Process email message to extract required data - IMPROVED"""
    try:
        # Get email body text (both HTML and plain text)
        email_body = ""
        html_body = ""
        plain_body = ""
        
        if msg.is_multipart():
            for part in msg.walk():
                content_type = part.get_content_type()
                
                if content_type == "text/plain":
                    try:
                        plain_content = part.get_payload(decode=True).decode('utf-8', errors='ignore')
                        plain_body += plain_content
                    except:
                        pass
                        
                elif content_type == "text/html":
                    try:
                        html_content = part.get_payload(decode=True).decode('utf-8', errors='ignore')
                        html_body += html_content
                    except:
                        pass
        else:
            try:
                content = msg.get_payload(decode=True).decode('utf-8', errors='ignore')
                if msg.get_content_type() == "text/html":
                    html_body = content
                else:
                    plain_body = content
            except:
                pass
        
        # Use HTML body if available, otherwise plain body
        email_body = html_body if html_body else plain_body
        
        if not email_body:
            print("    No email body content found")
            return None
        
        # Identify bank
        bank = identify_bank(sender)
        if bank not in ['HDFC', 'IDFC']:
            print(f"    Unknown bank: {bank}")
            return None
        
        print(f"    Processing {bank} email")
        
        # Extract amount
        amount = extract_amount_from_email_body(email_body, bank)
        if amount is None:
            print(f"    No amount found in {bank} email")
            return None
        
        # Get email date (received date as statement date)
        email_date = msg.get('Date', '')
        if email_date:
            try:
                # Parse email date
                import email.utils
                email_datetime = email.utils.parsedate_to_datetime(email_date)
                statement_date = email_datetime.strftime('%d/%m/%Y')
            except:
                statement_date = datetime.now().strftime('%d/%m/%Y')
        else:
            statement_date = datetime.now().strftime('%d/%m/%Y')
        
        # Extract due date from email body
        due_date = extract_due_date_from_email_body(email_body)
        
        # Standardize statement date components
        date_formatted, month_name, year = standardize_date_components(statement_date)
        
        # Create record
        record = {
            'DATE': date_formatted,
            'MONTH': month_name,
            'YEAR': year,
            'BANK': bank,
            'AMOUNT': amount,
            'DUE_DATE': due_date,
            'EMAIL_SUBJECT': decode_header_value(msg.get("Subject", "")),
            'PROCESSED_TIME': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        }
        
        print(f"    Successfully extracted: {bank} ₹{amount} {month_name} {year}")
        return record
        
    except Exception as e:
        print(f"    Error processing email body: {e}")
        return None

print(" IMPROVED Email body parsing functions defined successfully!")
# Out:
#  IMPROVED Email body parsing functions defined successfully!

# %%
# Run the email body extraction
extracted_records = run_email_body_extraction(CONFIG)

print(f"\n EXTRACTION COMPLETE!")
print(f" Records extracted: {len(extracted_records)}")
if extracted_records:
    sample_record = extracted_records[0]
    print(f" Sample record: {sample_record}")
# Out:
#  STARTING EMAIL BODY DATA EXTRACTION
#  Processing email content directly (No PDF downloads)
# ============================================================
# 2025-08-13 00:38:22,480 - INFO -  Successfully connected to email server
#  Processing Year: 2025
#    Searching: 01-Jan-2025 to 01-Jan-2026
# 2025-08-13 00:38:23,037 - INFO - Searching emails from 01-Jan-2025 to 31-Dec-2025
# 2025-08-13 00:38:23,714 - INFO - Found 5 emails with criteria: (FROM "Emailstatements.cards@hdfcbank.net" SINCE "01-Jan-2025" BEFORE "31-Dec-2025")
# 2025-08-13 00:38:24,663 - INFO - Found 5 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2025" BEFORE "31-Dec-2025") (FROM "hdfc")
# 2025-08-13 00:38:24,957 - INFO - Found 17 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2025" BEFORE "31-Dec-2025") (FROM "idfc")
#  Found 22 emails
#     Processing IDFC email
#     Found amount: ₹721.45 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 15-11-2022
#     Successfully extracted: IDFC ₹721.45 July 2025
#     Processing IDFC email
#     Found amount: ₹2024.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2024.0 January 2025
#     Processing IDFC email
#     Found amount: ₹2025.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2025.0 March 2025
#     Processing HDFC email
#     Found amount: ₹100.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹100.0 April 2025
#     Processing HDFC email
#     Found amount: ₹10198.67 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-04-2025
#     Successfully extracted: HDFC ₹10198.67 March 2025
#     Processing IDFC email
#     Found amount: ₹399.0 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 15-11-2022
#     Successfully extracted: IDFC ₹399.0 July 2025
#     Processing IDFC email
#     Found amount: ₹2025.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2025.0 May 2025
#     Processing IDFC email
#     Found amount: ₹588.82 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 15-11-2022
#     Successfully extracted: IDFC ₹588.82 May 2025
#     Processing IDFC email
#     Found amount: ₹8491.72 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 15-11-2022
#     Successfully extracted: IDFC ₹8491.72 April 2025
#     Processing IDFC email
#     Found amount: ₹1553.39 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 09-03-2025
#     Successfully extracted: IDFC ₹1553.39 February 2025
#     Processing HDFC email
#     Found amount: ₹10223.47 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 07-03-2025
#     Successfully extracted: HDFC ₹10223.47 February 2025
#     Processing HDFC email
#     Found amount: ₹10223.3 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-02-2025
#     Successfully extracted: HDFC ₹10223.3 January 2025
#     Processing IDFC email
#     Found amount: ₹2025.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2025.0 June 2025
#     Processing IDFC email
#     Found amount: ₹2100.99 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 15-11-2022
#     Successfully extracted: IDFC ₹2100.99 May 2025
#     Processing IDFC email
#     Found amount: ₹2025.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2025.0 August 2025
#     Processing IDFC email
#     Found amount: ₹2025.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2025.0 February 2025
#     Processing IDFC email
#     Found amount: ₹998.0 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 15-11-2022
#     Successfully extracted: IDFC ₹998.0 June 2025
#     Processing IDFC email
#     Found amount: ₹588.82 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 15-11-2022
#     Successfully extracted: IDFC ₹588.82 June 2025
#     Processing IDFC email
#     Found amount: ₹2025.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2025.0 April 2025
#     Processing IDFC email
#     Found amount: ₹2025.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2025.0 July 2025
#     Processing HDFC email
#     Found amount: ₹100.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹100.0 April 2025
#     Processing IDFC email
#     Found amount: ₹3618.23 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 06-04-2025
#     Successfully extracted: IDFC ₹3618.23 March 2025
#  Extracted 22 records from 2025
#
#  Processing Year: 2024
#    Searching: 01-Jan-2024 to 01-Jan-2025
# 2025-08-13 00:38:41,849 - INFO - Searching emails from 01-Jan-2024 to 31-Dec-2024
# 2025-08-13 00:38:42,657 - INFO - Found 18 emails with criteria: (FROM "Emailstatements.cards@hdfcbank.net" SINCE "01-Jan-2024" BEFORE "31-Dec-2024")
# 2025-08-13 00:38:43,579 - INFO - Found 19 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2024" BEFORE "31-Dec-2024") (FROM "hdfc")
# 2025-08-13 00:38:43,876 - INFO - Found 28 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2024" BEFORE "31-Dec-2024") (FROM "idfc")
#  Found 47 emails
#     Processing IDFC email
#     Found amount: ₹17406.64 using pattern: (?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)...
#     Found due date: 22-01-2024
#     Successfully extracted: IDFC ₹17406.64 January 2024
#     Processing IDFC email
#     Found amount: ₹4553.32 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 10-07-2024
#     Successfully extracted: IDFC ₹4553.32 June 2024
#     Processing IDFC email
#     Found amount: ₹8332.96 using pattern: (?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)...
#     Found due date: 22-02-2024
#     Successfully extracted: IDFC ₹8332.96 February 2024
#     Processing HDFC email
#     Found amount: ₹10223.13 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-01-2025
#     Successfully extracted: HDFC ₹10223.13 December 2024
#     Processing IDFC email
#     Found amount: ₹588.82 using pattern: (?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)...
#     Found due date: 20-05-2024
#     Successfully extracted: IDFC ₹588.82 May 2024
#     Processing IDFC email
#     Found amount: ₹2024.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2024.0 December 2024
#     Processing HDFC email
#     Found amount: ₹164.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-12-2024
#     Successfully extracted: HDFC ₹164.0 November 2024
#     Processing HDFC email
#     Found amount: ₹10394.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-04-2024
#     Successfully extracted: HDFC ₹10394.0 March 2024
#     Processing HDFC email
#     Found amount: ₹2760.01 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-02-2024
#     Successfully extracted: HDFC ₹2760.01 January 2024
#     Processing IDFC email
#     Found amount: ₹2024.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2024.0 November 2024
#     Processing HDFC email
#     Found amount: ₹100.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     Found due date: 12/12/2024
#     Successfully extracted: HDFC ₹100.0 December 2024
#     Processing IDFC email
#     Found amount: ₹2024.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2024.0 March 2024
#     Processing HDFC email
#     Found amount: ₹100.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹100.0 December 2024
#     Processing HDFC email
#     Found amount: ₹4501.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-06-2024
#     Successfully extracted: HDFC ₹4501.0 May 2024
#     Processing HDFC email
#     Found amount: ₹100.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹100.0 May 2024
#     Processing IDFC email
#     Found amount: ₹2023.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2023.0 January 2024
#     Processing IDFC email
#     Found amount: ₹2024.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2024.0 May 2024
#     Processing IDFC email
#     Found amount: ₹4107.48 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 07-07-2024
#     Successfully extracted: IDFC ₹4107.48 June 2024
#     Processing IDFC email
#     Found amount: ₹2024.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2024.0 June 2024
#     Processing HDFC email
#     Found amount: ₹6047.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-11-2024
#     Successfully extracted: HDFC ₹6047.0 October 2024
#     Processing IDFC email
#     Found amount: ₹2024.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2024.0 July 2024
#     Processing IDFC email
#     Found amount: ₹1986.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹1986.0 November 2024
#     Processing IDFC email
#     Found amount: ₹2024.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2024.0 October 2024
#     Processing IDFC email
#     Found amount: ₹10556.65 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 09-08-2024
#     Successfully extracted: IDFC ₹10556.65 July 2024
#     Processing HDFC email
#     Found amount: ₹2759.69 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 06-03-2024
#     Successfully extracted: HDFC ₹2759.69 February 2024
#     Processing HDFC email
#     Found amount: ₹7023.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-10-2024
#     Successfully extracted: HDFC ₹7023.0 September 2024
#     Processing IDFC email
#     Found amount: ₹2024.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2024.0 February 2024
#     Processing IDFC email
#     Found amount: ₹9951.33 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 09-09-2024
#     Successfully extracted: IDFC ₹9951.33 August 2024
#     Processing HDFC email
#     Found amount: ₹4042.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-08-2024
#     Successfully extracted: HDFC ₹4042.0 July 2024
#     Processing IDFC email
#     Found amount: ₹15396.28 using pattern: (?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)...
#     Found due date: 22-03-2024
#     Successfully extracted: IDFC ₹15396.28 March 2024
#     Processing IDFC email
#     Found amount: ₹2024.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2024.0 April 2024
#     Processing IDFC email
#     Found amount: ₹9350.65 using pattern: (?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)...
#     Found due date: 22-04-2024
#     Successfully extracted: IDFC ₹9350.65 April 2024
#     Processing IDFC email
#     Found amount: ₹6831.16 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 07-10-2024
#     Successfully extracted: IDFC ₹6831.16 September 2024
#     Processing HDFC email
#     Found amount: ₹5035.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-07-2024
#     Successfully extracted: HDFC ₹5035.0 June 2024
#     Processing IDFC email
#     Found amount: ₹100.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     Found due date: 04-10-2024
#     Successfully extracted: IDFC ₹100.0 September 2024
#     Processing IDFC email
#     Found amount: ₹9256.58 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 06-08-2024
#     Successfully extracted: IDFC ₹9256.58 July 2024
#     Processing HDFC email
#     Found amount: ₹5694.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 06-03-2024
#     Successfully extracted: HDFC ₹5694.0 February 2024
#     Processing HDFC email
#     Found amount: ₹11747.96 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-12-2024
#     Successfully extracted: HDFC ₹11747.96 November 2024
#     Processing IDFC email
#     Found amount: ₹9504.0 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 06-11-2024
#     Successfully extracted: IDFC ₹9504.0 October 2024
#     Processing HDFC email
#     Found amount: ₹100.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹100.0 March 2024
#     Processing HDFC email
#     Found amount: ₹7689.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-02-2024
#     Successfully extracted: HDFC ₹7689.0 January 2024
#     Processing HDFC email
#     Found amount: ₹44717.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-05-2024
#     Successfully extracted: HDFC ₹44717.0 April 2024
#     Processing HDFC email
#     Found amount: ₹4231.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-09-2024
#     Successfully extracted: HDFC ₹4231.0 August 2024
#     Processing IDFC email
#     Found amount: ₹2024.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2024.0 August 2024
#     Processing IDFC email
#     Found amount: ₹3490.2 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 06-09-2024
#     Successfully extracted: IDFC ₹3490.2 August 2024
#     Processing IDFC email
#     Found amount: ₹11675.48 using pattern: (?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)...
#     Found due date: 22-05-2024
#     Successfully extracted: IDFC ₹11675.48 May 2024
#     Processing IDFC email
#     Found amount: ₹2024.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2024.0 September 2024
#  Extracted 47 records from 2024
#
#  Processing Year: 2023
#    Searching: 01-Jan-2023 to 01-Jan-2024
# 2025-08-13 00:39:22,048 - INFO - Searching emails from 01-Jan-2023 to 31-Dec-2023
# 2025-08-13 00:39:22,663 - INFO - Found 22 emails with criteria: (FROM "Emailstatements.cards@hdfcbank.net" SINCE "01-Jan-2023" BEFORE "31-Dec-2023")
# 2025-08-13 00:39:23,576 - INFO - Found 22 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2023" BEFORE "31-Dec-2023") (FROM "hdfc")
# 2025-08-13 00:39:23,880 - INFO - Found 25 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2023" BEFORE "31-Dec-2023") (FROM "idfc")
#  Found 47 emails
#     Processing IDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2022.0 January 2023
#     Processing IDFC email
#     Found amount: ₹2023.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2023.0 March 2023
#     Processing HDFC email
#     Found amount: ₹3955.11 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-04-2023
#     Successfully extracted: HDFC ₹3955.11 March 2023
#     Processing HDFC email
#     Found amount: ₹2759.87 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-08-2023
#     Successfully extracted: HDFC ₹2759.87 July 2023
#     Processing HDFC email
#     Found amount: ₹7179.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 07-03-2023
#     Successfully extracted: HDFC ₹7179.0 February 2023
#     Processing IDFC email
#     Found amount: ₹2023.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2023.0 June 2023
#     Processing IDFC email
#     Found amount: ₹4522.93 using pattern: (?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)...
#     Found due date: 22-07-2023
#     Successfully extracted: IDFC ₹4522.93 July 2023
#     Processing HDFC email
#     Found amount: ₹10275.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-09-2023
#     Successfully extracted: HDFC ₹10275.0 August 2023
#     Processing HDFC email
#     Found amount: ₹2760.63 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-12-2023
#     Successfully extracted: HDFC ₹2760.63 November 2023
#     Processing HDFC email
#     Found amount: ₹13671.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-05-2023
#     Successfully extracted: HDFC ₹13671.0 April 2023
#     Processing IDFC email
#     Found amount: ₹2023.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2023.0 October 2023
#     Processing HDFC email
#     Found amount: ₹2758.49 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-06-2023
#     Successfully extracted: HDFC ₹2758.49 May 2023
#     Processing HDFC email
#     Found amount: ₹8195.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-04-2023
#     Successfully extracted: HDFC ₹8195.0 March 2023
#     Processing IDFC email
#     Found amount: ₹9860.82 using pattern: (?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)...
#     Found due date: 21-10-2023
#     Successfully extracted: IDFC ₹9860.82 October 2023
#     Processing IDFC email
#     Found amount: ₹2023.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2023.0 April 2023
#     Processing IDFC email
#     Found amount: ₹2023.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2023.0 February 2023
#     Processing IDFC email
#     Found amount: ₹6467.82 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 13-03-2023
#     Successfully extracted: IDFC ₹6467.82 February 2023
#     Processing HDFC email
#     Found amount: ₹6431.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-02-2023
#     Successfully extracted: HDFC ₹6431.0 January 2023
#     Processing HDFC email
#     Found amount: ₹9042.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-11-2023
#     Successfully extracted: HDFC ₹9042.0 October 2023
#     Processing HDFC email
#     Found amount: ₹2760.32 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-01-2024
#     Successfully extracted: HDFC ₹2760.32 December 2023
#     Processing IDFC email
#     Found amount: ₹6810.72 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 10-05-2023
#     Successfully extracted: IDFC ₹6810.72 April 2023
#     Processing HDFC email
#     Found amount: ₹18743.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-10-2023
#     Successfully extracted: HDFC ₹18743.0 September 2023
#     Processing HDFC email
#     Found amount: ₹2760.56 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-09-2023
#     Successfully extracted: HDFC ₹2760.56 August 2023
#     Processing IDFC email
#     Found amount: ₹4609.72 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 09-06-2023
#     Successfully extracted: IDFC ₹4609.72 May 2023
#     Processing IDFC email
#     Found amount: ₹8537.49 using pattern: (?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)...
#     Found due date: 22-11-2023
#     Successfully extracted: IDFC ₹8537.49 November 2023
#     Processing HDFC email
#     Found amount: ₹5045.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-01-2024
#     Successfully extracted: HDFC ₹5045.0 December 2023
#     Processing IDFC email
#     Found amount: ₹2023.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2023.0 August 2023
#     Processing HDFC email
#     Found amount: ₹2760.25 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-10-2023
#     Successfully extracted: HDFC ₹2760.25 September 2023
#     Processing HDFC email
#     Found amount: ₹7634.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-08-2023
#     Successfully extracted: HDFC ₹7634.0 July 2023
#     Processing IDFC email
#     Found amount: ₹7809.06 using pattern: (?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)...
#     Found due date: 22-12-2023
#     Successfully extracted: IDFC ₹7809.06 December 2023
#     Processing IDFC email
#     Found amount: ₹2023.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2023.0 December 2023
#     Processing IDFC email
#     Found amount: ₹2023.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2023.0 May 2023
#     Processing IDFC email
#     Found amount: ₹7455.77 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 08-02-2023
#     Successfully extracted: IDFC ₹7455.77 January 2023
#     Processing IDFC email
#     Found amount: ₹2898.79 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 10-04-2023
#     Successfully extracted: IDFC ₹2898.79 March 2023
#     Processing IDFC email
#     Found amount: ₹9890.49 using pattern: (?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)...
#     Found due date: 22-06-2023
#     Successfully extracted: IDFC ₹9890.49 June 2023
#     Processing HDFC email
#     Found amount: ₹2759.18 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-07-2023
#     Successfully extracted: HDFC ₹2759.18 June 2023
#     Processing HDFC email
#     Found amount: ₹2759.8 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-05-2023
#     Successfully extracted: HDFC ₹2759.8 April 2023
#     Processing HDFC email
#     Found amount: ₹4364.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-07-2023
#     Successfully extracted: HDFC ₹4364.0 June 2023
#     Processing IDFC email
#     Found amount: ₹2023.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2023.0 November 2023
#     Processing IDFC email
#     Found amount: ₹9890.49 using pattern: (?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)...
#     Found due date: 22-06-2023
#     Successfully extracted: IDFC ₹9890.49 June 2023
#     Processing HDFC email
#     Found amount: ₹5055.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-12-2023
#     Successfully extracted: HDFC ₹5055.0 November 2023
#     Processing IDFC email
#     Found amount: ₹9967.86 using pattern: (?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)...
#     Found due date: 22-09-2023
#     Successfully extracted: IDFC ₹9967.86 September 2023
#     Processing HDFC email
#     Found amount: ₹2759.94 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-11-2023
#     Successfully extracted: HDFC ₹2759.94 October 2023
#     Processing IDFC email
#     Found amount: ₹2023.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2023.0 July 2023
#     Processing HDFC email
#     Found amount: ₹12145.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-06-2023
#     Successfully extracted: HDFC ₹12145.0 May 2023
#     Processing IDFC email
#     Found amount: ₹7505.26 using pattern: (?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)...
#     Found due date: 22-08-2023
#     Successfully extracted: IDFC ₹7505.26 August 2023
#     Processing IDFC email
#     Found amount: ₹2023.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2023.0 September 2023
#  Extracted 47 records from 2023
#
#  Processing Year: 2022
#    Searching: 01-Jan-2022 to 01-Jan-2023
# 2025-08-13 00:40:08,912 - INFO - Searching emails from 01-Jan-2022 to 31-Dec-2022
# 2025-08-13 00:40:09,578 - INFO - Found 12 emails with criteria: (FROM "Emailstatements.cards@hdfcbank.net" SINCE "01-Jan-2022" BEFORE "31-Dec-2022")
# 2025-08-13 00:40:10,494 - INFO - Found 19 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2022" BEFORE "31-Dec-2022") (FROM "hdfc")
# 2025-08-13 00:40:10,799 - INFO - Found 20 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2022" BEFORE "31-Dec-2022") (FROM "idfc")
#  Found 39 emails
#     Processing IDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     Found due date: 10-05-2022
#     Successfully extracted: IDFC ₹2022.0 April 2022
#     Processing IDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2022.0 February 2022
#     Processing IDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2022.0 July 2022
#     Processing HDFC email
#     Found amount: ₹4635.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-07-2022
#     Successfully extracted: HDFC ₹4635.0 June 2022
#     Processing IDFC email
#     Found amount: ₹1922.62 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 08-06-2022
#     Successfully extracted: IDFC ₹1922.62 May 2022
#     Processing HDFC email
#     Found amount: ₹4791.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-09-2022
#     Successfully extracted: HDFC ₹4791.0 August 2022
#     Processing HDFC email
#     Found amount: ₹8045.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-01-2023
#     Successfully extracted: HDFC ₹8045.0 December 2022
#     Processing HDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2022.0 July 2022
#     Processing HDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2022.0 May 2022
#     Processing HDFC email
#     Found amount: ₹8761.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-08-2022
#     Successfully extracted: HDFC ₹8761.0 July 2022
#     Processing IDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2022.0 November 2022
#     Processing IDFC email
#     Found amount: ₹17425.33 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 10-10-2022
#     Successfully extracted: IDFC ₹17425.33 September 2022
#     Processing HDFC email
#     Found amount: ₹8222.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-10-2022
#     Successfully extracted: HDFC ₹8222.0 September 2022
#     Processing IDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2022.0 May 2022
#     Processing IDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2022.0 October 2022
#     Processing IDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2022.0 April 2022
#     Processing IDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2022.0 March 2022
#     Processing IDFC email
#     Found amount: ₹9485.92 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 09-01-2023
#     Successfully extracted: IDFC ₹9485.92 December 2022
#     Processing HDFC email
#     Found amount: ₹16143.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-05-2022
#     Successfully extracted: HDFC ₹16143.0 April 2022
#     Processing IDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2022.0 September 2022
#     Processing IDFC email
#     Found amount: ₹8998.7 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 09-09-2022
#     Successfully extracted: IDFC ₹8998.7 August 2022
#     Processing HDFC email
#     Found amount: ₹5068.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-06-2022
#     Successfully extracted: HDFC ₹5068.0 May 2022
#     Processing HDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2022.0 March 2022
#     Processing HDFC email
#     Found amount: ₹10914.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-04-2022
#     Successfully extracted: HDFC ₹10914.0 March 2022
#     Processing IDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2022.0 June 2022
#     Processing IDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2022.0 December 2022
#     Processing HDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2022.0 February 2022
#     Processing IDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2021.0 January 2022
#     Processing IDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2022.0 August 2022
#     Processing HDFC email
#     Found amount: ₹6918.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-11-2022
#     Successfully extracted: HDFC ₹6918.0 October 2022
#     Processing HDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2021.0 January 2022
#     Processing HDFC email
#     Found amount: ₹28208.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 07-03-2022
#     Successfully extracted: HDFC ₹28208.0 February 2022
#     Processing IDFC email
#     Found amount: ₹7439.66 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 10-12-2022
#     Successfully extracted: IDFC ₹7439.66 November 2022
#     Processing HDFC email
#     Found amount: ₹11396.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-12-2022
#     Successfully extracted: HDFC ₹11396.0 November 2022
#     Processing HDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2022.0 April 2022
#     Processing HDFC email
#     Found amount: ₹2022.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2022.0 June 2022
#     Processing IDFC email
#     Found amount: ₹8757.22 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 11-07-2022
#     Successfully extracted: IDFC ₹8757.22 June 2022
#     Processing IDFC email
#     Found amount: ₹2598.02 using pattern: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0...
#     Found due date: 09-08-2022
#     Successfully extracted: IDFC ₹2598.02 July 2022
#     Processing HDFC email
#     Found amount: ₹2227.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-02-2022
#     Successfully extracted: HDFC ₹2227.0 January 2022
#  Extracted 39 records from 2022
#
#  Processing Year: 2021
#    Searching: 01-Jan-2021 to 01-Jan-2022
# 2025-08-13 00:40:46,586 - INFO - Searching emails from 01-Jan-2021 to 31-Dec-2021
# 2025-08-13 00:40:47,197 - INFO - Found 12 emails with criteria: (FROM "Emailstatements.cards@hdfcbank.net" SINCE "01-Jan-2021" BEFORE "31-Dec-2021")
# 2025-08-13 00:40:48,099 - INFO - Found 24 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2021" BEFORE "31-Dec-2021") (FROM "hdfc")
# 2025-08-13 00:40:48,397 - INFO - Found 5 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2021" BEFORE "31-Dec-2021") (FROM "idfc")
#  Found 29 emails
#     Processing HDFC email
#     Found amount: ₹1800.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 07-03-2021
#     Successfully extracted: HDFC ₹1800.0 February 2021
#     Processing HDFC email
#     Found amount: ₹4300.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-05-2021
#     Successfully extracted: HDFC ₹4300.0 April 2021
#     Processing HDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2021.0 May 2021
#     Processing HDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2021.0 December 2021
#     Processing HDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2021.0 June 2021
#     Processing HDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2021.0 November 2021
#     Processing HDFC email
#     Found amount: ₹22261.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-06-2021
#     Successfully extracted: HDFC ₹22261.0 May 2021
#     Processing HDFC email
#     Found amount: ₹2579.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-02-2021
#     Successfully extracted: HDFC ₹2579.0 January 2021
#     Processing HDFC email
#     Found amount: ₹2799.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-12-2021
#     Successfully extracted: HDFC ₹2799.0 November 2021
#     Processing HDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2021.0 March 2021
#     Processing HDFC email
#     Found amount: ₹546.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-11-2021
#     Successfully extracted: HDFC ₹546.0 October 2021
#     Processing HDFC email
#     Found amount: ₹2020.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2020.0 January 2021
#     Processing HDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2021.0 August 2021
#     Processing HDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2021.0 April 2021
#     Processing IDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2021.0 September 2021
#     Processing IDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2021.0 December 2021
#     Processing HDFC email
#     Found amount: ₹5712.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-01-2022
#     Successfully extracted: HDFC ₹5712.0 December 2021
#     Processing HDFC email
#     Found amount: ₹2849.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-07-2021
#     Successfully extracted: HDFC ₹2849.0 June 2021
#     Processing IDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2021.0 October 2021
#     Processing HDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2021.0 October 2021
#     Processing HDFC email
#     Found amount: ₹2425.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-08-2021
#     Successfully extracted: HDFC ₹2425.0 July 2021
#     Processing IDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2021.0 November 2021
#     Processing HDFC email
#     Found amount: ₹310.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-09-2021
#     Successfully extracted: HDFC ₹310.0 August 2021
#     Processing HDFC email
#     Found amount: ₹2740.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-04-2021
#     Successfully extracted: HDFC ₹2740.0 March 2021
#     Processing IDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: IDFC ₹2021.0 August 2021
#     Processing HDFC email
#     Found amount: ₹2845.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 05-10-2021
#     Successfully extracted: HDFC ₹2845.0 September 2021
#     Processing HDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2021.0 February 2021
#     Processing HDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2021.0 September 2021
#     Processing HDFC email
#     Found amount: ₹2021.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2021.0 July 2021
#  Extracted 29 records from 2021
#
#  Processing Year: 2020
#    Searching: 01-Jan-2020 to 01-Jan-2021
# 2025-08-13 00:41:04,349 - INFO - Searching emails from 01-Jan-2020 to 31-Dec-2020
# 2025-08-13 00:41:04,959 - INFO - Found 1 emails with criteria: (FROM "Emailstatements.cards@hdfcbank.net" SINCE "01-Jan-2020" BEFORE "31-Dec-2020")
# 2025-08-13 00:41:05,891 - INFO - Found 13 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2020" BEFORE "31-Dec-2020") (FROM "hdfc")
#  Found 13 emails
#     Processing HDFC email
#     Found amount: ₹2020.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2020.0 October 2020
#     Processing HDFC email
#     Found amount: ₹2020.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2020.0 May 2020
#     Processing HDFC email
#     Found amount: ₹2020.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2020.0 February 2020
#     Processing HDFC email
#     Found amount: ₹2020.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2020.0 December 2020
#     Processing HDFC email
#     Found amount: ₹2020.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2020.0 August 2020
#     Processing HDFC email
#     Found amount: ₹2020.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2020.0 September 2020
#     Processing HDFC email
#     Found amount: ₹2020.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2020.0 April 2020
#     Processing HDFC email
#     Found amount: ₹2020.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2020.0 March 2020
#     Processing HDFC email
#     Found amount: ₹2937.0 using pattern: \b([0-9,]+\.[0-9]{2})\b...
#     Found due date: 04-01-2021
#     Successfully extracted: HDFC ₹2937.0 December 2020
#     Processing HDFC email
#     Found amount: ₹2020.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2020.0 June 2020
#     Processing HDFC email
#     Found amount: ₹2019.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2019.0 January 2020
#     Processing HDFC email
#     Found amount: ₹2020.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2020.0 November 2020
#     Processing HDFC email
#     Found amount: ₹2020.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2020.0 July 2020
#  Extracted 13 records from 2020
#
#  Processing Year: 2019
#    Searching: 01-Jan-2019 to 01-Jan-2020
# 2025-08-13 00:41:11,193 - INFO - Searching emails from 01-Jan-2019 to 31-Dec-2019
# 2025-08-13 00:41:12,749 - INFO - Found 12 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2019" BEFORE "31-Dec-2019") (FROM "hdfc")
#  Found 12 emails
#     Processing HDFC email
#     Found amount: ₹2018.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2018.0 January 2019
#     Processing HDFC email
#     Found amount: ₹2019.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2019.0 August 2019
#     Processing HDFC email
#     Found amount: ₹2019.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2019.0 April 2019
#     Processing HDFC email
#     Found amount: ₹2019.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2019.0 February 2019
#     Processing HDFC email
#     Found amount: ₹2019.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2019.0 October 2019
#     Processing HDFC email
#     Found amount: ₹2019.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2019.0 July 2019
#     Processing HDFC email
#     Found amount: ₹2019.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2019.0 December 2019
#     Processing HDFC email
#     Found amount: ₹2019.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2019.0 June 2019
#     Processing HDFC email
#     Found amount: ₹2019.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2019.0 November 2019
#     Processing HDFC email
#     Found amount: ₹2019.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2019.0 September 2019
#     Processing HDFC email
#     Found amount: ₹2019.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2019.0 March 2019
#     Processing HDFC email
#     Found amount: ₹2019.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2019.0 May 2019
#  Extracted 12 records from 2019
#
#  Processing Year: 2018
#    Searching: 01-Jan-2018 to 01-Jan-2019
# 2025-08-13 00:41:18,233 - INFO - Searching emails from 01-Jan-2018 to 31-Dec-2018
# 2025-08-13 00:41:19,822 - INFO - Found 10 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2018" BEFORE "31-Dec-2018") (FROM "hdfc")
#  Found 10 emails
#     Processing HDFC email
#     Found amount: ₹2018.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2018.0 January 2018
#     Processing HDFC email
#     Found amount: ₹1000.0 using pattern: (?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)...
#     No due date found
#     Successfully extracted: HDFC ₹1000.0 May 2018
#     Processing HDFC email
#     Found amount: ₹100.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹100.0 July 2018
#     Processing HDFC email
#     Found amount: ₹2018.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2018.0 August 2018
#     Processing HDFC email
#     Found amount: ₹2018.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2018.0 August 2025
#     Processing HDFC email
#     Found amount: ₹2018.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2018.0 September 2018
#     Processing HDFC email
#     Found amount: ₹2018.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2018.0 March 2018
#     Processing HDFC email
#     Found amount: ₹200.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹200.0 June 2018
#     Processing HDFC email
#     Found amount: ₹2018.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2018.0 December 2018
#     Processing HDFC email
#     Found amount: ₹2017.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹2017.0 February 2018
#  Extracted 10 records from 2018
#
#  Processing Year: 2017
#    Searching: 01-Jan-2017 to 01-Jan-2018
# 2025-08-13 00:41:25,047 - INFO - Searching emails from 01-Jan-2017 to 31-Dec-2017
# 2025-08-13 00:41:26,672 - INFO - Found 10 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2017" BEFORE "31-Dec-2017") (FROM "hdfc")
#  Found 10 emails
#     Processing HDFC email
#     Found amount: ₹100.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹100.0 October 2017
#     Processing HDFC email
#     Found amount: ₹100.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹100.0 September 2017
#     Processing HDFC email
#     Found amount: ₹100.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹100.0 August 2017
#     Processing HDFC email
#     Found amount: ₹100.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹100.0 June 2017
#     Processing HDFC email
#     Found amount: ₹100.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹100.0 July 2017
#     Processing HDFC email
#     Found amount: ₹1999.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹1999.0 February 2017
#     Processing HDFC email
#     Found amount: ₹1999.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹1999.0 May 2017
#     Processing HDFC email
#     Found amount: ₹1999.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹1999.0 April 2017
#     Processing HDFC email
#     Found amount: ₹1999.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹1999.0 March 2017
#     Processing HDFC email
#     Found amount: ₹1999.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹1999.0 January 2017
#  Extracted 10 records from 2017
#
#  Processing Year: 2016
#    Searching: 01-Jan-2016 to 01-Jan-2017
# 2025-08-13 00:41:32,433 - INFO - Searching emails from 01-Jan-2016 to 31-Dec-2016
# 2025-08-13 00:41:33,935 - INFO - Found 2 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2016" BEFORE "31-Dec-2016") (FROM "hdfc")
#  Found 2 emails
#     Processing HDFC email
#     Found amount: ₹1999.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹1999.0 November 2016
#     Processing HDFC email
#     Found amount: ₹1999.0 using pattern: \b([1-9][0-9,]{2,})\b...
#     No due date found
#     Successfully extracted: HDFC ₹1999.0 December 2016
#  Extracted 2 records from 2016
#
#  Processing Year: 2015
#    Searching: 01-Jan-2015 to 01-Jan-2016
# 2025-08-13 00:41:35,928 - INFO - Searching emails from 01-Jan-2015 to 31-Dec-2015
#  No emails for 2015. Stopping.
# EXCEL FILE CREATED SUCCESSFULLY!
# Location: ../data/raw_emails\output\credit_card_email_data.xlsx
#  Total Records: 231
# Banks: IDFC, HDFC
#  Total Amount: ₹977,219.04
#  Date Range: 02/01/2024 to 24/12/2022
#
#  EMAIL BODY EXTRACTION COMPLETED!
#  Final Results: 231 records extracted
#
#  EXTRACTION COMPLETE!
#  Records extracted: 231
#  Sample record: {'DATE': '23/07/2025', 'MONTH': 'July', 'YEAR': '2025', 'BANK': 'IDFC', 'AMOUNT': 721.45, 'DUE_DATE': '15-11-2022', 'EMAIL_SUBJECT': 'Your FIRST Millennia Credit Card Statement', 'PROCESSED_TIME': '2025-08-13 00:38:26'}

# %%
def debug_single_email(config, max_emails=3):
    """Debug email body extraction with detailed logging"""
    print(" DEBUGGING EMAIL BODY EXTRACTION")
    print("=" * 50)
    
    mail = connect_to_email(config)
    if not mail:
        return
    
    try:
        # Get recent emails for testing
        start_date = datetime(2025, 1, 1)
        end_date = datetime(2025, 12, 31)
        email_ids = search_credit_card_emails_between(mail, config, start_date, end_date)
        
        if not email_ids:
            print(" No emails found for debugging")
            return
            
        print(f" Testing with {min(max_emails, len(email_ids))} recent emails")
        
        for i, email_id in enumerate(email_ids[:max_emails]):
            print(f"\n DEBUG EMAIL #{i+1} (ID: {email_id.decode()})")
            print("-" * 30)
            
            try:
                # Fetch email
                typ, msg_data = mail.fetch(email_id, '(RFC822)')
                
                for response_part in msg_data:
                    if isinstance(response_part, tuple):
                        msg = email.message_from_bytes(response_part[1])
                        
                        # Debug email headers
                        sender = decode_header_value(msg.get("From", ""))
                        subject = decode_header_value(msg.get("Subject", ""))
                        date = msg.get("Date", "")
                        
                        print(f" From: {sender}")
                        print(f" Subject: {subject}")
                        print(f" Date: {date}")
                        
                        # Debug bank identification
                        bank = identify_bank(sender)
                        print(f" Bank Identified: {bank}")
                        
                        # Extract email body with debug info
                        email_body = ""
                        body_parts = []
                        
                        if msg.is_multipart():
                            print(" Multipart email - extracting text parts...")
                            for part in msg.walk():
                                content_type = part.get_content_type()
                                print(f"   Part type: {content_type}")
                                
                                if content_type == "text/plain":
                                    try:
                                        part_content = part.get_payload(decode=True).decode('utf-8', errors='ignore')
                                        email_body += part_content
                                        body_parts.append(f"Plain text: {len(part_content)} chars")
                                    except Exception as e:
                                        print(f"   Error decoding plain text: {e}")
                                        
                                elif content_type == "text/html":
                                    try:
                                        html_content = part.get_payload(decode=True).decode('utf-8', errors='ignore')
                                        # Simple HTML to text conversion
                                        import re
                                        text_content = re.sub('<[^<]+?>', ' ', html_content)
                                        email_body += text_content
                                        body_parts.append(f"HTML text: {len(text_content)} chars")
                                    except Exception as e:
                                        print(f"   Error decoding HTML: {e}")
                        else:
                            print(" Single part email...")
                            try:
                                email_body = msg.get_payload(decode=True).decode('utf-8', errors='ignore')
                                body_parts.append(f"Single part: {len(email_body)} chars")
                            except Exception as e:
                                print(f"   Error decoding single part: {e}")
                        
                        print(f" Body parts found: {body_parts}")
                        print(f" Total body length: {len(email_body)} characters")
                        
                        if email_body:
                            # Show first 500 characters of body for debugging
                            print(f" Body preview (first 500 chars):")
                            print("   " + email_body[:500].replace('\n', ' ').replace('\r', ' '))
                            print()
                            
                            # Test amount extraction with debug
                            print(" TESTING AMOUNT EXTRACTION:")
                            amount = extract_amount_from_email_body(email_body, bank)
                            print(f"   Amount found: {amount}")
                            
                            # Show what patterns we're looking for
                            print("   Testing patterns:")
                            amount_patterns = [
                                r'Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
                                r'Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
                                r'Amount Payable[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)',
                                r'(?:Rs\.?\s*|INR\s*|₹\s*)([0-9,]+\.?[0-9]*)'
                            ]
                            
                            for pattern in amount_patterns:
                                matches = re.findall(pattern, email_body, re.IGNORECASE)
                                if matches:
                                    print(f"   Pattern matched: {pattern}")
                                    print(f"      Matches: {matches}")
                                    break
                            else:
                                print("  No amount patterns matched")
                            
                            # Test due date extraction
                            print(" TESTING DUE DATE EXTRACTION:")
                            due_date = extract_due_date_from_email_body(email_body)
                            print(f"   Due date found: {due_date}")
                            
                        else:
                            print(" No email body content extracted!")
                            
            except Exception as e:
                print(f" Error processing email {i+1}: {e}")
                import traceback
                traceback.print_exc()
                
    finally:
        try:
            mail.close()
            mail.logout()
        except:
            pass

# Run debugging
debug_single_email(CONFIG, max_emails=2)
# Out:
#  DEBUGGING EMAIL BODY EXTRACTION
# ==================================================
# 2025-08-13 00:32:27,371 - INFO -  Successfully connected to email server
# 2025-08-13 00:32:27,887 - INFO - Searching emails from 01-Jan-2025 to 31-Dec-2025
# 2025-08-13 00:32:28,469 - INFO - Found 5 emails with criteria: (FROM "Emailstatements.cards@hdfcbank.net" SINCE "01-Jan-2025" BEFORE "31-Dec-2025")
# 2025-08-13 00:32:29,389 - INFO - Found 5 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2025" BEFORE "31-Dec-2025") (FROM "hdfc")
# 2025-08-13 00:32:29,678 - INFO - Found 17 emails with criteria: (SUBJECT "statement" SINCE "01-Jan-2025" BEFORE "31-Dec-2025") (FROM "idfc")
#  Testing with 2 recent emails
#
#  DEBUG EMAIL #1 (ID: 84442)
# ------------------------------
#  From: IDFC FIRST Bank <statement@idfcfirstbank.com>
#  Subject: Your FIRST Millennia Credit Card Statement
#  Date: Wed, 23 Jul 2025 22:40:42 +0530
#  Bank Identified: IDFC
#  Multipart email - extracting text parts...
#    Part type: multipart/mixed
#    Part type: multipart/related
#    Part type: multipart/alternative
#    Part type: text/html
#    Part type: application/octet-stream
#  Body parts found: ['HTML text: 3101 chars']
#  Total body length: 3101 characters
#  Body preview (first 500 chars):
#             IDFC FIRST Bank           outlookfix{ width:0 !important;}  table {border-spacing: 0 !important; border-collapse: collapse !important;}  img{max-width:100%; height:auto; display:block; border:0px;} ..clear{display:none !important;}                                                        Dear Cardmember,   We hope transacting with your FIRST Millennia Credit Card ending with XXXX1344 has been a smooth-sailing experience.   With offers curated just for you, make sure to   check out our 300
#
#  TESTING AMOUNT EXTRACTION:
#    Amount found: 721.45
#    Testing patterns:
#    Pattern matched: Total Amount Due[:\s]*(?:Rs\.?\s*|INR\s*|₹\s*)?([0-9,]+\.?[0-9]*)
#       Matches: ['721.45']
#  TESTING DUE DATE EXTRACTION:
#    Due date found:
#
#  DEBUG EMAIL #2 (ID: 78459)
# ------------------------------
#  From: IDFC FIRST Bank <statement@idfcfirstbank.com>
#  Subject: Your Account Statement for the month of December 2024
#  Date: Thu, 02 Jan 2025 16:12:09 +0530
#  Bank Identified: IDFC
#  Multipart email - extracting text parts...
#    Part type: multipart/mixed
#    Part type: text/html
#    Part type: application/octet-stream
#  Body parts found: ['HTML text: 6434 chars']
#  Total body length: 6434 characters
#  Body preview (first 500 chars):
#                window.onload = function()          var date = new Date().getFullYear();         document.getElementById("year").innerHTML = date;                   	  		  			 		  <table width="530" class="deviceWidth" border="0" cellpadding="0" cellspacing="0" align="center" style="border:1px solid e6e6e6; border-right:1px solid e6e6e6" 				  					    			    				  				                          				     Dear Mr. Surendhar .,  					    					    					 					        				        Enclosed in this email is
#
#  TESTING AMOUNT EXTRACTION:
#    Amount found: None
#    Testing patterns:
#   No amount patterns matched
#  TESTING DUE DATE EXTRACTION:
#    Due date found:
